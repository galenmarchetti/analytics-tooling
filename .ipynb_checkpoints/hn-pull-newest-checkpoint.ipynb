# %%
import requests as r
import time
from datetime import datetime
from datetime import timedelta

'''
All HN API requests are constructed using the following reference: https://github.com/HackerNews/API
'''


base_url = "https://hacker-news.firebaseio.com/v0/"
human_display_item_url = "https://news.ycombinator.com/item?id="
new_stories_slug = "newstories"
item_slug = "item/"
json_append_slug = ".json"

# %%
### Get Story IDs for the newest stories from the HN New Stories endpoint
new_stories_response = r.get(base_url + new_stories_slug + json_append_slug)
new_stories_json = new_stories_response.json()

# %%
# returns datetime.timedelta object representing time between execution and story posting
def get_td_from_story(story):
    story_unix_time = story['time']
    story_datetime = datetime.fromtimestamp(story_unix_time)
    timedelta_since_post = datetime.now() - story_datetime
    return timedelta_since_post

def get_comments_per_minute_from_story(timedelta_since_post, num_comments):
    minutes_since_post = timedelta_since_post.seconds / 60
    comments_per_minute = (num_comments * 1.0) / minutes_since_post
    return comments_per_minute

def format_timedelta(timedelta_since_post):
    hours_since_post, remainder = divmod(timedelta_since_post.seconds, 3600)
    minutes_since_post, seconds = divmod(remainder, 60)
    time_since_post = str(hours_since_post) + 'h' + str(minutes_since_post) + 'm'
    return time_since_post

def get_comment_timestamps(story_json, delay_in_seconds):
    comments = story_json['kids']
    print("Total number of timestamps we're getting: " + str(len(comments)))
    comment_timestamps = []
    for comment_id in comments:
        comment_response = r.get(base_url + item_slug + str(comment_id) + json_append_slug)
        comment = comment_response.json()
        comment_timestamps.append(comment['time'])
        time.sleep(delay_in_seconds)
    return comment_timestamps

# Structure: story_id: {num_comments, }
story_info_tracker = {}
num_stories = len(new_stories_json)
for i, story_id in enumerate(new_stories_json):
    story_response = r.get(base_url + item_slug + str(story_id) + json_append_slug)
    story = story_response.json()
    if 'descendants' in story:
        num_comments = story['descendants']
    elif ('dead' in story and story['dead']):
        continue
    else:
        raise Exception("Couldn't find descendants in story: " + str(story))
    title = story['title']
    timedelta_since_post = get_td_from_story(story)
    comments_per_minute = get_comments_per_minute_from_story(timedelta_since_post, num_comments)
    time_since_post = format_timedelta(timedelta_since_post)
    if num_comments > 0:
        print("Pulling comment info for story with " + str(num_comments) + " comments")
        comment_timestamps = get_comment_timestamps(story, 0.1)
    else:
        comment_timestamps = []
    story_info_tracker[story_id] = {
        'num_comments': num_comments,
        'title': title,
        'timedelta_since_post': timedelta_since_post,
        'time_since_post': time_since_post,
        'comments_per_minute': comments_per_minute,
        'url': human_display_item_url + str(story_id),
        'comment_timestamps': comment_timestamps,
    }
    print("Pulled info for story " + str(i) + "/" + str(num_stories))
# Out:
# Pulling comment info for story with 7 comments
# Total number of timestamps we're getting: 4
# Pulled info for story 0/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 1/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 2/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 3/500
# Pulled info for story 4/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 5/500
# Pulling comment info for story with 5 comments
# Total number of timestamps we're getting: 4
# Pulled info for story 6/500
# Pulled info for story 7/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 8/500
# Pulling comment info for story with 17 comments
# Total number of timestamps we're getting: 6
# Pulled info for story 9/500
# Pulled info for story 10/500
# Pulling comment info for story with 30 comments
# Total number of timestamps we're getting: 11
# Pulled info for story 11/500
# Pulled info for story 12/500
# Pulled info for story 13/500
# Pulled info for story 14/500
# Pulled info for story 15/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 16/500
# Pulling comment info for story with 5 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 17/500
# Pulling comment info for story with 33 comments
# Total number of timestamps we're getting: 7
# Pulled info for story 18/500
# Pulled info for story 19/500
# Pulled info for story 20/500
# Pulled info for story 21/500
# Pulled info for story 22/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 23/500
# Pulled info for story 24/500
# Pulling comment info for story with 4 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 25/500
# Pulled info for story 26/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 27/500
# Pulled info for story 28/500
# Pulled info for story 29/500
# Pulling comment info for story with 13 comments
# Total number of timestamps we're getting: 8
# Pulled info for story 30/500
# Pulled info for story 31/500
# Pulled info for story 32/500
# Pulled info for story 33/500
# Pulled info for story 34/500
# Pulled info for story 35/500
# Pulling comment info for story with 31 comments
# Total number of timestamps we're getting: 8
# Pulled info for story 36/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 37/500
# Pulled info for story 38/500
# Pulled info for story 39/500
# Pulled info for story 40/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 41/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 42/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 43/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 44/500
# Pulled info for story 45/500
# Pulled info for story 46/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 47/500
# Pulling comment info for story with 16 comments
# Total number of timestamps we're getting: 12
# Pulled info for story 48/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 49/500
# Pulled info for story 50/500
# Pulled info for story 51/500
# Pulled info for story 52/500
# Pulled info for story 53/500
# Pulled info for story 54/500
# Pulled info for story 55/500
# Pulled info for story 56/500
# Pulling comment info for story with 6 comments
# Total number of timestamps we're getting: 5
# Pulled info for story 57/500
# Pulling comment info for story with 6 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 58/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 59/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 5
# Pulled info for story 60/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 61/500
# Pulled info for story 62/500
# Pulled info for story 63/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 64/500
# Pulled info for story 65/500
# Pulled info for story 66/500
# Pulled info for story 67/500
# Pulled info for story 68/500
# Pulled info for story 69/500
# Pulled info for story 70/500
# Pulled info for story 71/500
# Pulled info for story 72/500
# Pulled info for story 73/500
# Pulling comment info for story with 32 comments
# Total number of timestamps we're getting: 13
# Pulled info for story 74/500
# Pulled info for story 75/500
# Pulled info for story 76/500
# Pulled info for story 77/500
# Pulled info for story 78/500
# Pulled info for story 79/500
# Pulled info for story 80/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 81/500
# Pulled info for story 82/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 83/500
# Pulled info for story 84/500
# Pulled info for story 85/500
# Pulled info for story 86/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 87/500
# Pulling comment info for story with 132 comments
# Total number of timestamps we're getting: 25
# Pulled info for story 88/500
# Pulled info for story 89/500
# Pulled info for story 90/500
# Pulled info for story 91/500
# Pulled info for story 92/500
# Pulled info for story 93/500
# Pulling comment info for story with 41 comments
# Total number of timestamps we're getting: 5
# Pulled info for story 94/500
# Pulling comment info for story with 158 comments
# Total number of timestamps we're getting: 17
# Pulled info for story 95/500
# Pulled info for story 96/500
# Pulled info for story 97/500
# Pulled info for story 98/500
# Pulled info for story 99/500
# Pulled info for story 100/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 101/500
# Pulled info for story 102/500
# Pulled info for story 103/500
# Pulling comment info for story with 14 comments
# Total number of timestamps we're getting: 9
# Pulled info for story 104/500
# Pulled info for story 105/500
# Pulling comment info for story with 53 comments
# Total number of timestamps we're getting: 7
# Pulled info for story 106/500
# Pulled info for story 107/500
# Pulling comment info for story with 62 comments
# Total number of timestamps we're getting: 19
# Pulled info for story 108/500
# Pulled info for story 109/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 110/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 111/500
# Pulled info for story 112/500
# Pulling comment info for story with 6 comments
# Total number of timestamps we're getting: 4
# Pulled info for story 113/500
# Pulled info for story 114/500
# Pulling comment info for story with 62 comments
# Total number of timestamps we're getting: 11
# Pulled info for story 115/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 116/500
# Pulled info for story 117/500
# Pulled info for story 118/500
# Pulling comment info for story with 32 comments
# Total number of timestamps we're getting: 11
# Pulled info for story 119/500
# Pulled info for story 120/500
# Pulled info for story 121/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 122/500
# Pulled info for story 123/500
# Pulled info for story 124/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 125/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 126/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 127/500
# Pulled info for story 128/500
# Pulling comment info for story with 11 comments
# Total number of timestamps we're getting: 6
# Pulled info for story 129/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 130/500
# Pulled info for story 131/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 132/500
# Pulled info for story 133/500
# Pulled info for story 134/500
# Pulled info for story 135/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 136/500
# Pulling comment info for story with 144 comments
# Total number of timestamps we're getting: 31
# Pulled info for story 137/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 138/500
# Pulling comment info for story with 7 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 139/500
# Pulled info for story 140/500
# Pulled info for story 141/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 142/500
# Pulled info for story 143/500
# Pulled info for story 144/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 145/500
# Pulled info for story 146/500
# Pulled info for story 147/500
# Pulled info for story 148/500
# Pulling comment info for story with 19 comments
# Total number of timestamps we're getting: 5
# Pulled info for story 149/500
# Pulled info for story 150/500
# Pulled info for story 151/500
# Pulled info for story 152/500
# Pulled info for story 153/500
# Pulled info for story 154/500
# Pulled info for story 155/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 156/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 157/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 158/500
# Pulled info for story 159/500
# Pulled info for story 160/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 161/500
# Pulling comment info for story with 4 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 162/500
# Pulled info for story 163/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 164/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 165/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 166/500
# Pulled info for story 167/500
# Pulled info for story 168/500
# Pulled info for story 169/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 170/500
# Pulled info for story 171/500
# Pulled info for story 172/500
# Pulling comment info for story with 24 comments
# Total number of timestamps we're getting: 18
# Pulled info for story 173/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 174/500
# Pulled info for story 175/500
# Pulled info for story 176/500
# Pulled info for story 177/500
# Pulled info for story 178/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 179/500
# Pulled info for story 180/500
# Pulled info for story 181/500
# Pulling comment info for story with 11 comments
# Total number of timestamps we're getting: 4
# Pulled info for story 182/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 183/500
# Pulled info for story 184/500
# Pulled info for story 185/500
# Pulled info for story 186/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 187/500
# Pulled info for story 188/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 189/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 190/500
# Pulled info for story 191/500
# Pulled info for story 192/500
# Pulled info for story 193/500
# Pulled info for story 194/500
# Pulled info for story 195/500
# Pulled info for story 196/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 197/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 198/500
# Pulled info for story 199/500
# Pulled info for story 200/500
# Pulled info for story 201/500
# Pulling comment info for story with 11 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 202/500
# Pulling comment info for story with 78 comments
# Total number of timestamps we're getting: 42
# Pulled info for story 203/500
# Pulling comment info for story with 10 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 204/500
# Pulling comment info for story with 87 comments
# Total number of timestamps we're getting: 21
# Pulled info for story 205/500
# Pulled info for story 206/500
# Pulled info for story 207/500
# Pulling comment info for story with 29 comments
# Total number of timestamps we're getting: 11
# Pulled info for story 208/500
# Pulling comment info for story with 41 comments
# Total number of timestamps we're getting: 12
# Pulled info for story 209/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 210/500
# Pulling comment info for story with 6 comments
# Total number of timestamps we're getting: 6
# Pulled info for story 211/500
# Pulling comment info for story with 34 comments
# Total number of timestamps we're getting: 6
# Pulled info for story 212/500
# Pulling comment info for story with 24 comments
# Total number of timestamps we're getting: 4
# Pulled info for story 213/500
# Pulled info for story 214/500
# Pulled info for story 215/500
# Pulling comment info for story with 398 comments
# Total number of timestamps we're getting: 70
# Pulled info for story 216/500
# Pulled info for story 217/500
# Pulled info for story 218/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 219/500
# Pulling comment info for story with 41 comments
# Total number of timestamps we're getting: 10
# Pulled info for story 220/500
# Pulled info for story 221/500
# Pulled info for story 222/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 223/500
# Pulling comment info for story with 11 comments
# Total number of timestamps we're getting: 4
# Pulled info for story 224/500
# Pulling comment info for story with 45 comments
# Total number of timestamps we're getting: 8
# Pulled info for story 225/500
# Pulling comment info for story with 12 comments
# Total number of timestamps we're getting: 9
# Pulled info for story 226/500
# Pulling comment info for story with 37 comments
# Total number of timestamps we're getting: 12
# Pulled info for story 227/500
# Pulling comment info for story with 8 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 228/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 229/500
# Pulled info for story 230/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 231/500
# Pulled info for story 232/500
# Pulled info for story 233/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 234/500
# Pulled info for story 235/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 236/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 237/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 238/500
# Pulled info for story 239/500
# Pulled info for story 240/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 241/500
# Pulling comment info for story with 70 comments
# Total number of timestamps we're getting: 18
# Pulled info for story 242/500
# Pulled info for story 243/500
# Pulled info for story 244/500
# Pulled info for story 245/500
# Pulled info for story 246/500
# Pulled info for story 247/500
# Pulling comment info for story with 4 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 248/500
# Pulled info for story 249/500
# Pulling comment info for story with 83 comments
# Total number of timestamps we're getting: 12
# Pulled info for story 250/500
# Pulled info for story 251/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 252/500
# Pulled info for story 253/500
# Pulled info for story 254/500
# Pulling comment info for story with 183 comments
# Total number of timestamps we're getting: 8
# Pulled info for story 255/500
# Pulling comment info for story with 11 comments
# Total number of timestamps we're getting: 4
# Pulled info for story 256/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 257/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 258/500
# Pulled info for story 259/500
# Pulled info for story 260/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 261/500
# Pulling comment info for story with 9 comments
# Total number of timestamps we're getting: 4
# Pulled info for story 262/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 263/500
# Pulled info for story 264/500
# Pulled info for story 265/500
# Pulled info for story 266/500
# Pulled info for story 267/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 268/500
# Pulled info for story 269/500
# Pulled info for story 270/500
# Pulled info for story 271/500
# Pulled info for story 272/500
# Pulled info for story 273/500
# Pulled info for story 274/500
# Pulled info for story 275/500
# Pulling comment info for story with 55 comments
# Total number of timestamps we're getting: 10
# Pulled info for story 276/500
# Pulled info for story 277/500
# Pulled info for story 278/500
# Pulled info for story 279/500
# Pulled info for story 280/500
# Pulled info for story 281/500
# Pulled info for story 282/500
# Pulled info for story 283/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 284/500
# Pulled info for story 285/500
# Pulling comment info for story with 13 comments
# Total number of timestamps we're getting: 4
# Pulled info for story 286/500
# Pulled info for story 287/500
# Pulled info for story 288/500
# Pulled info for story 289/500
# Pulled info for story 290/500
# Pulled info for story 291/500
# Pulling comment info for story with 12 comments
# Total number of timestamps we're getting: 9
# Pulled info for story 292/500
# Pulling comment info for story with 28 comments
# Total number of timestamps we're getting: 15
# Pulled info for story 293/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 294/500
# Pulling comment info for story with 115 comments
# Total number of timestamps we're getting: 6
# Pulled info for story 295/500
# Pulled info for story 296/500
# Pulling comment info for story with 36 comments
# Total number of timestamps we're getting: 12
# Pulled info for story 297/500
# Pulled info for story 298/500
# Pulled info for story 299/500
# Pulling comment info for story with 43 comments
# Total number of timestamps we're getting: 21
# Pulled info for story 300/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 301/500
# Pulled info for story 302/500
# Pulled info for story 303/500
# Pulled info for story 304/500
# Pulled info for story 305/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 306/500
# Pulled info for story 307/500
# Pulled info for story 308/500
# Pulled info for story 309/500
# Pulled info for story 310/500
# Pulled info for story 311/500
# Pulled info for story 312/500
# Pulled info for story 313/500
# Pulled info for story 314/500
# Pulled info for story 315/500
# Pulled info for story 316/500
# Pulled info for story 317/500
# Pulled info for story 318/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 319/500
# Pulled info for story 320/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 321/500
# Pulled info for story 322/500
# Pulling comment info for story with 37 comments
# Total number of timestamps we're getting: 13
# Pulled info for story 323/500
# Pulled info for story 324/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 325/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 326/500
# Pulling comment info for story with 4 comments
# Total number of timestamps we're getting: 4
# Pulled info for story 327/500
# Pulling comment info for story with 76 comments
# Total number of timestamps we're getting: 16
# Pulled info for story 328/500
# Pulled info for story 329/500
# Pulled info for story 330/500
# Pulled info for story 331/500
# Pulled info for story 332/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 333/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 334/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 335/500
# Pulled info for story 336/500
# Pulled info for story 337/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 338/500
# Pulled info for story 339/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 340/500
# Pulled info for story 341/500
# Pulled info for story 342/500
# Pulled info for story 343/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 344/500
# Pulled info for story 345/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 346/500
# Pulled info for story 347/500
# Pulled info for story 348/500
# Pulling comment info for story with 8 comments
# Total number of timestamps we're getting: 4
# Pulled info for story 349/500
# Pulled info for story 350/500
# Pulled info for story 351/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 352/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 353/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 354/500
# Pulled info for story 355/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 356/500
# Pulling comment info for story with 13 comments
# Total number of timestamps we're getting: 7
# Pulled info for story 357/500
# Pulling comment info for story with 103 comments
# Total number of timestamps we're getting: 24
# Pulled info for story 358/500
# Pulling comment info for story with 22 comments
# Total number of timestamps we're getting: 7
# Pulled info for story 359/500
# Pulled info for story 360/500
# Pulled info for story 361/500
# Pulling comment info for story with 6 comments
# Total number of timestamps we're getting: 6
# Pulled info for story 362/500
# Pulled info for story 363/500
# Pulled info for story 364/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 365/500
# Pulled info for story 366/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 367/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 368/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 369/500
# Pulling comment info for story with 4 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 370/500
# Pulled info for story 371/500
# Pulled info for story 372/500
# Pulled info for story 373/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 374/500
# Pulled info for story 375/500
# Pulled info for story 376/500
# Pulled info for story 377/500
# Pulled info for story 378/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 379/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 380/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 381/500
# Pulled info for story 382/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 383/500
# Pulled info for story 384/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 385/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 386/500
# Pulled info for story 387/500
# Pulled info for story 388/500
# Pulled info for story 389/500
# Pulling comment info for story with 5 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 390/500
# Pulled info for story 391/500
# Pulled info for story 392/500
# Pulled info for story 393/500
# Pulled info for story 395/500
# Pulled info for story 396/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 397/500
# Pulled info for story 398/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 399/500
# Pulled info for story 400/500
# Pulled info for story 401/500
# Pulled info for story 402/500
# Pulled info for story 403/500
# Pulled info for story 404/500
# Pulled info for story 405/500
# Pulled info for story 406/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 407/500
# Pulled info for story 408/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 409/500
# Pulling comment info for story with 5 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 410/500
# Pulling comment info for story with 91 comments
# Total number of timestamps we're getting: 10
# Pulled info for story 411/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 412/500
# Pulled info for story 413/500
# Pulled info for story 414/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 415/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 416/500
# Pulling comment info for story with 45 comments
# Total number of timestamps we're getting: 11
# Pulled info for story 417/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 418/500
# Pulling comment info for story with 268 comments
# Total number of timestamps we're getting: 13
# Pulled info for story 419/500
# Pulled info for story 420/500
# Pulling comment info for story with 125 comments
# Total number of timestamps we're getting: 21
# Pulled info for story 421/500
# Pulling comment info for story with 10 comments
# Total number of timestamps we're getting: 9
# Pulled info for story 422/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 423/500
# Pulled info for story 424/500
# Pulling comment info for story with 68 comments
# Total number of timestamps we're getting: 25
# Pulled info for story 425/500
# Pulled info for story 426/500
# Pulled info for story 427/500
# Pulled info for story 428/500
# Pulling comment info for story with 144 comments
# Total number of timestamps we're getting: 44
# Pulled info for story 429/500
# Pulled info for story 430/500
# Pulling comment info for story with 19 comments
# Total number of timestamps we're getting: 6
# Pulled info for story 431/500
# Pulled info for story 432/500
# Pulled info for story 433/500
# Pulled info for story 434/500
# Pulled info for story 435/500
# Pulled info for story 436/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 437/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 438/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 439/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 440/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 441/500
# Pulled info for story 442/500
# Pulled info for story 443/500
# Pulled info for story 444/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 445/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 446/500
# Pulling comment info for story with 65 comments
# Total number of timestamps we're getting: 20
# Pulled info for story 447/500
# Pulled info for story 448/500
# Pulled info for story 449/500
# Pulled info for story 450/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 451/500
# Pulled info for story 452/500
# Pulled info for story 453/500
# Pulled info for story 454/500
# Pulled info for story 455/500
# Pulled info for story 456/500
# Pulled info for story 457/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 458/500
# Pulled info for story 459/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 460/500
# Pulled info for story 461/500
# Pulled info for story 462/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 463/500
# Pulled info for story 464/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 465/500
# Pulled info for story 466/500
# Pulled info for story 467/500
# Pulled info for story 468/500
# Pulled info for story 469/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 470/500
# Pulled info for story 471/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 472/500
# Pulled info for story 473/500
# Pulled info for story 474/500
# Pulled info for story 475/500
# Pulled info for story 476/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 477/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 478/500
# Pulled info for story 479/500
# Pulled info for story 480/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 481/500
# Pulling comment info for story with 2 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 482/500
# Pulling comment info for story with 18 comments
# Total number of timestamps we're getting: 11
# Pulled info for story 483/500
# Pulled info for story 484/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 485/500
# Pulling comment info for story with 3 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 486/500
# Pulling comment info for story with 40 comments
# Total number of timestamps we're getting: 12
# Pulled info for story 487/500
# Pulled info for story 488/500
# Pulling comment info for story with 1 comments
# Total number of timestamps we're getting: 1
# Pulled info for story 489/500
# Pulling comment info for story with 14 comments
# Total number of timestamps we're getting: 6
# Pulled info for story 490/500
# Pulling comment info for story with 5 comments
# Total number of timestamps we're getting: 4
# Pulled info for story 491/500
# Pulled info for story 492/500
# Pulled info for story 493/500
# Pulling comment info for story with 9 comments
# Total number of timestamps we're getting: 3
# Pulled info for story 494/500
# Pulling comment info for story with 4 comments
# Total number of timestamps we're getting: 2
# Pulled info for story 495/500
# Pulled info for story 496/500
# Pulled info for story 497/500
# Pulled info for story 498/500
# Pulled info for story 499/500

# %%
# Gets comments per minute from an array of unix timestamps representing comment times, and minutes in the past to consider recent.
def get_comments_per_minute_from_recent_comments(comment_unix_timestamp_array, minutes_to_consider_recent):
    recency_datetime = datetime.now() - timedelta(minutes=minutes_to_consider_recent)
    filtered_comments = [comment for comment in comment_unix_timestamp_array if comment >= recency_datetime.timestamp()]
    filtered_comments_sorted = sorted(filtered_comments)
    if len(filtered_comments_sorted) <= 1:
        return 0
    first_comment_timestamp = datetime.fromtimestamp(filtered_comments_sorted[0])
    last_comment_timestamp = datetime.fromtimestamp(filtered_comments_sorted[-1])
    timedelta_between_first_last_comment = last_comment_timestamp - first_comment_timestamp
    minutes_between_first_last_comment = (timedelta_between_first_last_comment.seconds * 1.0) / 60
    return (len(comment_unix_timestamp_array) * 1.0) / minutes_between_first_last_comment

def get_stories_with_recent_comment_velocity(stories, recency_in_minutes):
    stories_with_recent_comment_velocity = {}
    for story_id, story in stories.items():
        recent_comment_velocity = get_comments_per_minute_from_recent_comments(story['comment_timestamps'], recency_in_minutes)
        story['recent_comments_per_minute'] = recent_comment_velocity
        stories_with_recent_comment_velocity[story_id] = story
    return stories_with_recent_comment_velocity

def convert_sorted_stories_to_display_list(sorted_stories):
    original_list = [sorted_story[1] for sorted_story in sorted_stories]
    display_list = []
    for story in original_list:
        display_story = story.copy()
        if 'comment_timestamps' in display_story:
            del display_story['comment_timestamps']
        display_list.append(display_story)
    return display_list

def get_recent(sorted_stories_display_list, minutes_to_consider_recent):
    return [sorted_story for sorted_story in sorted_stories_display_list \
            if (sorted_story['timedelta_since_post'].seconds / 60) < minutes_to_consider_recent]


###
###
###

## EDIT THIS TO CHANGE DEFINITION OF "RECENT COMMENT"
MINUTES_TO_CONSIDER_RECENT = 30


###
###
###

## SORT AND FORMAT STORIES BY RELEVANT METRICS

story_info_tracker = get_stories_with_recent_comment_velocity(story_info_tracker, MINUTES_TO_CONSIDER_RECENT)

num_comments_sorted_stories = sorted(story_info_tracker.items(), key=lambda x: x[1]['num_comments'], reverse=True)
comment_velocity_sorted_stories = sorted(story_info_tracker.items(), key=lambda x: x[1]['comments_per_minute'], reverse=True)
recent_comment_velocity_sorted_stories = sorted(story_info_tracker.items(), key=lambda x: x[1]['recent_comments_per_minute'], reverse=True)

num_comments_sorted_stories_display = convert_sorted_stories_to_display_list(num_comments_sorted_stories)
comment_velocity_sorted_stories_display = convert_sorted_stories_to_display_list(comment_velocity_sorted_stories)
recent_comment_velocity_sorted_stories_display = convert_sorted_stories_to_display_list(recent_comment_velocity_sorted_stories)

# %%
# get_recent(comment_velocity_sorted_stories_display, (3 * 60))
# get_recent(num_comments_sorted_stories_display, (3*60))

recent_comment_velocity_sorted_stories_display
# Out:
# [{'num_comments': 144,
#   'title': 'The Mystery of the Bloomfield Bridge',
#   'timedelta_since_post': datetime.timedelta(seconds=57765, microseconds=385516),
#   'time_since_post': '16h2m',
#   'comments_per_minute': 0.14957153985977667,
#   'url': 'https://news.ycombinator.com/item?id=37359193',
#   'recent_comment_velocity': 15.808383233532934,
#   'recent_comments_per_minute': 15.808383233532934},
#  {'num_comments': 16,
#   'title': 'Show HN: Shaq, a CLI for Shazam',
#   'timedelta_since_post': datetime.timedelta(seconds=16987, microseconds=265104),
#   'time_since_post': '4h43m',
#   'comments_per_minute': 0.056513804674162595,
#   'url': 'https://news.ycombinator.com/item?id=37364124',
#   'recent_comment_velocity': 0.7733619763694951,
#   'recent_comments_per_minute': 2.4657534246575343},
#  {'num_comments': 7,
#   'title': 'Insights into prostitution by former receptionist presents harrowing reality',
#   'timedelta_since_post': datetime.timedelta(seconds=13035, microseconds=141327),
#   'time_since_post': '3h37m',
#   'comments_per_minute': 0.03222094361334868,
#   'url': 'https://news.ycombinator.com/item?id=37364753',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'The making of Starfield – one of the biggest stories ever told',
#   'timedelta_since_post': datetime.timedelta(seconds=13091, microseconds=378505),
#   'time_since_post': '3h38m',
#   'comments_per_minute': 0.004583301504850661,
#   'url': 'https://news.ycombinator.com/item?id=37364735',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 2,
#   'title': 'White House seeks input on tightening rules for risky pathogen research',
#   'timedelta_since_post': datetime.timedelta(seconds=13245, microseconds=816906),
#   'time_since_post': '3h40m',
#   'comments_per_minute': 0.009060022650056626,
#   'url': 'https://news.ycombinator.com/item?id=37364711',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Chrome extensions can steal passwords from websites',
#   'timedelta_since_post': datetime.timedelta(seconds=13247, microseconds=725866),
#   'time_since_post': '3h40m',
#   'comments_per_minute': 0.00452932739488186,
#   'url': 'https://news.ycombinator.com/item?id=37364709',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Antioxidants Vitamin C, E, and N-acetylcysteine stimulate tumor angiogenesis',
#   'timedelta_since_post': datetime.timedelta(seconds=13495, microseconds=127245),
#   'time_since_post': '3h44m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364671',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Rock Found in the Sahara Desert Could Be the First “Boomerang Meteorite”',
#   'timedelta_since_post': datetime.timedelta(seconds=13498, microseconds=302273),
#   'time_since_post': '3h44m',
#   'comments_per_minute': 0.004445102978218996,
#   'url': 'https://news.ycombinator.com/item?id=37364669',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 5,
#   'title': 'Ford Loses Nearly $60k for Every Electric Vehicle Sold',
#   'timedelta_since_post': datetime.timedelta(seconds=13613, microseconds=755115),
#   'time_since_post': '3h46m',
#   'comments_per_minute': 0.02203775802541688,
#   'url': 'https://news.ycombinator.com/item?id=37364647',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Understanding Americans’ Gonzo Relationship to Drug Use',
#   'timedelta_since_post': datetime.timedelta(seconds=13630, microseconds=4845),
#   'time_since_post': '3h47m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364644',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Microsoft is killing the classic Windows WordPad app after almost 3 decades',
#   'timedelta_since_post': datetime.timedelta(seconds=13640, microseconds=163080),
#   'time_since_post': '3h47m',
#   'comments_per_minute': 0.00439882697947214,
#   'url': 'https://news.ycombinator.com/item?id=37364642',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 17,
#   'title': 'DOS Game Club',
#   'timedelta_since_post': datetime.timedelta(seconds=13824, microseconds=691432),
#   'time_since_post': '3h50m',
#   'comments_per_minute': 0.07378472222222222,
#   'url': 'https://news.ycombinator.com/item?id=37364611',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Clotting proteins linked to Long Covid’s brain fog',
#   'timedelta_since_post': datetime.timedelta(seconds=13850, microseconds=465394),
#   'time_since_post': '3h50m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364606',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 30,
#   'title': "PSA: Don't base your business around Discord.7yr account banned for posting ASNs",
#   'timedelta_since_post': datetime.timedelta(seconds=13852, microseconds=655041),
#   'time_since_post': '3h50m',
#   'comments_per_minute': 0.12994513427663876,
#   'url': 'https://news.ycombinator.com/item?id=37364605',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Burning Man has turned into a kind of Fyre Fest type thing this year',
#   'timedelta_since_post': datetime.timedelta(seconds=13865, microseconds=910598),
#   'time_since_post': '3h51m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364603',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Critically ill UK teen in legal fight with NHS',
#   'timedelta_since_post': datetime.timedelta(seconds=13944, microseconds=73139),
#   'time_since_post': '3h52m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364594',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Chico, Creating a Spanish Dataset',
#   'timedelta_since_post': datetime.timedelta(seconds=13966, microseconds=228700),
#   'time_since_post': '3h52m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364589',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Lamborghini Plans to ‘Go Crazy’ with Paddle-Controlled Torque Vectoring',
#   'timedelta_since_post': datetime.timedelta(seconds=14178, microseconds=44563),
#   'time_since_post': '3h56m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364558',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Company releases first renderings of a new city proposed for Solano County',
#   'timedelta_since_post': datetime.timedelta(seconds=14203, microseconds=198326),
#   'time_since_post': '3h56m',
#   'comments_per_minute': 0.004224459621206787,
#   'url': 'https://news.ycombinator.com/item?id=37364551',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 5,
#   'title': 'WordPad will be removed in a future release of Windows',
#   'timedelta_since_post': datetime.timedelta(seconds=14233, microseconds=650505),
#   'time_since_post': '3h57m',
#   'comments_per_minute': 0.02107777699711937,
#   'url': 'https://news.ycombinator.com/item?id=37364546',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 33,
#   'title': 'Why There Is No Moral ‘Right to Strike’',
#   'timedelta_since_post': datetime.timedelta(seconds=14237, microseconds=385434),
#   'time_since_post': '3h57m',
#   'comments_per_minute': 0.139074243169207,
#   'url': 'https://news.ycombinator.com/item?id=37364544',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Did D-Wave show quantum advantage in 2023?',
#   'timedelta_since_post': datetime.timedelta(seconds=14331, microseconds=439180),
#   'time_since_post': '3h58m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364536',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Microsoft releases PowerToys’ with Crop and Lock',
#   'timedelta_since_post': datetime.timedelta(seconds=14343, microseconds=605205),
#   'time_since_post': '3h59m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364534',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'How would room-temperature superconductors change science?',
#   'timedelta_since_post': datetime.timedelta(seconds=14520, microseconds=794297),
#   'time_since_post': '4h2m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364509',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': "Building a micro-computer in Colombia 1980's",
#   'timedelta_since_post': datetime.timedelta(seconds=14583, microseconds=974766),
#   'time_since_post': '4h3m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364497',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'The Institute for Rebooting Social Media',
#   'timedelta_since_post': datetime.timedelta(seconds=14794, microseconds=140215),
#   'time_since_post': '4h6m',
#   'comments_per_minute': 0.00405569825604975,
#   'url': 'https://news.ycombinator.com/item?id=37364469',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': "The state of optimus-manager explained by it's developer",
#   'timedelta_since_post': datetime.timedelta(seconds=14799, microseconds=612072),
#   'time_since_post': '4h6m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364464',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 4,
#   'title': "AI Shouldn't Decide What's True",
#   'timedelta_since_post': datetime.timedelta(seconds=14880, microseconds=783331),
#   'time_since_post': '4h8m',
#   'comments_per_minute': 0.016129032258064516,
#   'url': 'https://news.ycombinator.com/item?id=37364454',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'The Way to Succeed in Learning',
#   'timedelta_since_post': datetime.timedelta(seconds=14887, microseconds=804436),
#   'time_since_post': '4h8m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364452',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Ask HN: Alternative News Websites/Feeds',
#   'timedelta_since_post': datetime.timedelta(seconds=15038, microseconds=967404),
#   'time_since_post': '4h10m',
#   'comments_per_minute': 0.0039898922729086315,
#   'url': 'https://news.ycombinator.com/item?id=37364419',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Re-Imagining the Command Line Interpreter',
#   'timedelta_since_post': datetime.timedelta(seconds=15094, microseconds=395937),
#   'time_since_post': '4h11m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364412',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Software Testing',
#   'timedelta_since_post': datetime.timedelta(seconds=15194, microseconds=589433),
#   'time_since_post': '4h13m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364394',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 13,
#   'title': 'Found in a Library Book',
#   'timedelta_since_post': datetime.timedelta(seconds=15230, microseconds=765622),
#   'time_since_post': '4h13m',
#   'comments_per_minute': 0.05121470781352593,
#   'url': 'https://news.ycombinator.com/item?id=37364388',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': "Why McDonald's Ice Cream Machines Are Always Broken and How to Fix Them",
#   'timedelta_since_post': datetime.timedelta(seconds=15332, microseconds=46134),
#   'time_since_post': '4h15m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364372',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'MouseWars',
#   'timedelta_since_post': datetime.timedelta(seconds=15394, microseconds=199718),
#   'time_since_post': '4h16m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364362',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Ask HN: Thoughts on isolating an “allegedly” offline site?',
#   'timedelta_since_post': datetime.timedelta(seconds=15608, microseconds=356780),
#   'time_since_post': '4h20m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364331',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Star Labs StarFighter Overview: 16 inch 4K Coreboot/Ryzen Linux laptop [video]',
#   'timedelta_since_post': datetime.timedelta(seconds=15615, microseconds=546206),
#   'time_since_post': '4h20m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364329',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Apple Provides Further Clarity on Why It Abandoned Plan to Detect CSAM',
#   'timedelta_since_post': datetime.timedelta(seconds=15711, microseconds=722368),
#   'time_since_post': '4h21m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364318',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 31,
#   'title': 'Show HN: I mirrored all the code from PyPI to GitHub and analysed it',
#   'timedelta_since_post': datetime.timedelta(seconds=15894, microseconds=891445),
#   'time_since_post': '4h24m',
#   'comments_per_minute': 0.11702529256323142,
#   'url': 'https://news.ycombinator.com/item?id=37364290',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 2,
#   'title': "Musk's X to collect biometric information and employment data",
#   'timedelta_since_post': datetime.timedelta(seconds=16025, microseconds=303251),
#   'time_since_post': '4h27m',
#   'comments_per_minute': 0.00748829953198128,
#   'url': 'https://news.ycombinator.com/item?id=37364271',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Nobel Foundation reverses decision to invite Russian ambassador to awards',
#   'timedelta_since_post': datetime.timedelta(seconds=16048, microseconds=758090),
#   'time_since_post': '4h27m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364268',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Climate activists let down this Toorak driver’s tyre. He sees their point',
#   'timedelta_since_post': datetime.timedelta(seconds=16306, microseconds=20929),
#   'time_since_post': '4h31m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364232',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Ask HN: Bad Shopify Experiences?',
#   'timedelta_since_post': datetime.timedelta(seconds=16361, microseconds=204986),
#   'time_since_post': '4h32m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364223',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Full 64bit assembly OS – MenuetOS 1.48.60',
#   'timedelta_since_post': datetime.timedelta(seconds=16558, microseconds=365806),
#   'time_since_post': '4h35m',
#   'comments_per_minute': 0.0036236260417924875,
#   'url': 'https://news.ycombinator.com/item?id=37364189',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 2,
#   'title': 'Touch a camera to control your devices',
#   'timedelta_since_post': datetime.timedelta(seconds=16612, microseconds=802501),
#   'time_since_post': '4h36m',
#   'comments_per_minute': 0.007223693715386468,
#   'url': 'https://news.ycombinator.com/item?id=37364181',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 2,
#   'title': 'Burning Man festival-goers trapped in desert as rain turns site to mud',
#   'timedelta_since_post': datetime.timedelta(seconds=16735, microseconds=506531),
#   'time_since_post': '4h38m',
#   'comments_per_minute': 0.0071706005377950395,
#   'url': 'https://news.ycombinator.com/item?id=37364168',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 3,
#   'title': 'Fosstodon',
#   'timedelta_since_post': datetime.timedelta(seconds=16783, microseconds=592668),
#   'time_since_post': '4h39m',
#   'comments_per_minute': 0.010725138533039386,
#   'url': 'https://news.ycombinator.com/item?id=37364161',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Minor Issue',
#   'timedelta_since_post': datetime.timedelta(seconds=16794, microseconds=302451),
#   'time_since_post': '4h39m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364157',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'The Kelly criterion: How to size bets (2019)',
#   'timedelta_since_post': datetime.timedelta(seconds=16897, microseconds=473799),
#   'time_since_post': '4h41m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364140',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 2,
#   'title': 'Virtual-Reality School Is the Next Frontier of the School-Choice Movement',
#   'timedelta_since_post': datetime.timedelta(seconds=16950, microseconds=616113),
#   'time_since_post': '4h42m',
#   'comments_per_minute': 0.007079646017699115,
#   'url': 'https://news.ycombinator.com/item?id=37364131',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Nginx UI: Yet Another Nginx Web UI',
#   'timedelta_since_post': datetime.timedelta(seconds=17014, microseconds=727196),
#   'time_since_post': '4h43m',
#   'comments_per_minute': 0.0035265075819913014,
#   'url': 'https://news.ycombinator.com/item?id=37364120',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'When Do Annotator Demographics Matter?',
#   'timedelta_since_post': datetime.timedelta(seconds=17338, microseconds=150519),
#   'time_since_post': '4h48m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364076',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Parallels between playing Diablo 4 co-op and working with others',
#   'timedelta_since_post': datetime.timedelta(seconds=17342, microseconds=350545),
#   'time_since_post': '4h49m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364075',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Tech Giants Have Hired Red Team Hackers to Break Their AI Models',
#   'timedelta_since_post': datetime.timedelta(seconds=17443, microseconds=550318),
#   'time_since_post': '4h50m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364058',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Lenin was a mushroom (1991) [video]',
#   'timedelta_since_post': datetime.timedelta(seconds=17618, microseconds=741760),
#   'time_since_post': '4h53m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364036',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Play Llama2 and play it well',
#   'timedelta_since_post': datetime.timedelta(seconds=17644, microseconds=890528),
#   'time_since_post': '4h54m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364035',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'The Natural Number Game',
#   'timedelta_since_post': datetime.timedelta(seconds=17646, microseconds=36054),
#   'time_since_post': '4h54m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364034',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Jack Holloway, Project MAC researcher and respected programmer, dies at 77',
#   'timedelta_since_post': datetime.timedelta(seconds=17690, microseconds=192383),
#   'time_since_post': '4h54m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37364030',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 6,
#   'title': 'Mexico Became the Biggest User of the World’s Most Notorious Spy Tool',
#   'timedelta_since_post': datetime.timedelta(seconds=17800, microseconds=356767),
#   'time_since_post': '4h56m',
#   'comments_per_minute': 0.020224719101123594,
#   'url': 'https://news.ycombinator.com/item?id=37364022',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 6,
#   'title': 'Lenovo’s new 27-inch, 4K monitor offers glasses-free 3D',
#   'timedelta_since_post': datetime.timedelta(seconds=17840, microseconds=823748),
#   'time_since_post': '4h57m',
#   'comments_per_minute': 0.02017937219730942,
#   'url': 'https://news.ycombinator.com/item?id=37364014',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'SwissMicros – Keeping the iconic HP RPN calculators alive',
#   'timedelta_since_post': datetime.timedelta(seconds=18117, microseconds=959879),
#   'time_since_post': '5h1m',
#   'comments_per_minute': 0.003311806590495115,
#   'url': 'https://news.ycombinator.com/item?id=37363974',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 3,
#   'title': 'New Startup Lossless Wants to Build Conscious Artificial Intelligence',
#   'timedelta_since_post': datetime.timedelta(seconds=18262, microseconds=385548),
#   'time_since_post': '5h4m',
#   'comments_per_minute': 0.009856532690833425,
#   'url': 'https://news.ycombinator.com/item?id=37363945',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 2,
#   'title': 'New phone sparks worry China has found a way around U.S. tech limits',
#   'timedelta_since_post': datetime.timedelta(seconds=18280, microseconds=916452),
#   'time_since_post': '5h4m',
#   'comments_per_minute': 0.006564551422319475,
#   'url': 'https://news.ycombinator.com/item?id=37363943',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': "Debunked: Why you'll never have to pay for Facebook (2010)",
#   'timedelta_since_post': datetime.timedelta(seconds=18333, microseconds=617571),
#   'time_since_post': '5h5m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363932',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Young Japanese Find It Pays to Work Abroad',
#   'timedelta_since_post': datetime.timedelta(seconds=18395, microseconds=779719),
#   'time_since_post': '5h6m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363916',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Dual NVMe Card with Eight E1.S SSDs Achieves 55 GB/S Performance',
#   'timedelta_since_post': datetime.timedelta(seconds=18398, microseconds=937950),
#   'time_since_post': '5h6m',
#   'comments_per_minute': 0.0032612240460919667,
#   'url': 'https://news.ycombinator.com/item?id=37363915',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Be the browser’s mentor, not its micromanager (2022)',
#   'timedelta_since_post': datetime.timedelta(seconds=18436, microseconds=380525),
#   'time_since_post': '5h7m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363910',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Alleged corruption in Cambodia’s monkey farms taints global wildlife trade',
#   'timedelta_since_post': datetime.timedelta(seconds=18465, microseconds=551336),
#   'time_since_post': '5h7m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363902',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'When Our Tools Hold Us Back (2022)',
#   'timedelta_since_post': datetime.timedelta(seconds=18494, microseconds=746004),
#   'time_since_post': '5h8m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363895',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'How Apple is already using machine learning and AI in iOS',
#   'timedelta_since_post': datetime.timedelta(seconds=18527, microseconds=939920),
#   'time_since_post': '5h8m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363891',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Coffee Meets Bagel has been down for one week',
#   'timedelta_since_post': datetime.timedelta(seconds=18577, microseconds=88628),
#   'time_since_post': '5h9m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363884',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'How to create actionable developer personas',
#   'timedelta_since_post': datetime.timedelta(seconds=18629, microseconds=261202),
#   'time_since_post': '5h10m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363877',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'The Incest to Prostitution Pipeline',
#   'timedelta_since_post': datetime.timedelta(seconds=18687, microseconds=417556),
#   'time_since_post': '5h11m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363865',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Gambrinus: Leading the AI Revolution Beyond Big AI',
#   'timedelta_since_post': datetime.timedelta(seconds=18697, microseconds=586528),
#   'time_since_post': '5h11m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363864',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'As UAW seeks 4-day workweek, the idea gains ground with US workers',
#   'timedelta_since_post': datetime.timedelta(seconds=18794, microseconds=743410),
#   'time_since_post': '5h13m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363847',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 32,
#   'title': 'Microsoft is killing WordPad in Windows after 28 years',
#   'timedelta_since_post': datetime.timedelta(seconds=19077, microseconds=928229),
#   'time_since_post': '5h17m',
#   'comments_per_minute': 0.10064475546469571,
#   'url': 'https://news.ycombinator.com/item?id=37363809',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'My80sTV',
#   'timedelta_since_post': datetime.timedelta(seconds=19143, microseconds=945734),
#   'time_since_post': '5h19m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363801',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Session Hijacking Visual Exploitation',
#   'timedelta_since_post': datetime.timedelta(seconds=19408, microseconds=119167),
#   'time_since_post': '5h23m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363758',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'We host Ars, the finale and the 64-bit future',
#   'timedelta_since_post': datetime.timedelta(seconds=19423, microseconds=292577),
#   'time_since_post': '5h23m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363755',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'A Personal Study on Online Personal Note-Taking',
#   'timedelta_since_post': datetime.timedelta(seconds=19463, microseconds=471753),
#   'time_since_post': '5h24m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363749',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Quake Sparked a Filmmaking Revolution (2017)',
#   'timedelta_since_post': datetime.timedelta(seconds=19502, microseconds=676199),
#   'time_since_post': '5h25m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363746',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Copyright Office Issues Notice of Inquiry on Copyright and AI',
#   'timedelta_since_post': datetime.timedelta(seconds=19552, microseconds=867324),
#   'time_since_post': '5h25m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363736',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 3,
#   'title': 'Show HN: Political Compass Quiz Powered by ChatGPT',
#   'timedelta_since_post': datetime.timedelta(seconds=19620, microseconds=22105),
#   'time_since_post': '5h27m',
#   'comments_per_minute': 0.009174311926605505,
#   'url': 'https://news.ycombinator.com/item?id=37363723',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Covid-19 virus is evolving rapidly in white-tailed deer, new research finds',
#   'timedelta_since_post': datetime.timedelta(seconds=19648, microseconds=694305),
#   'time_since_post': '5h27m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363720',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': "Let's talk about payments, shall we?",
#   'timedelta_since_post': datetime.timedelta(seconds=19695, microseconds=847252),
#   'time_since_post': '5h28m',
#   'comments_per_minute': 0.0030464584920030465,
#   'url': 'https://news.ycombinator.com/item?id=37363708',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Rome Tools: The Rome project is officially discontinued',
#   'timedelta_since_post': datetime.timedelta(seconds=19762, microseconds=396747),
#   'time_since_post': '5h29m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363699',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Kyiv’s burgeoning weapons industry is projecting power far beyond the front line',
#   'timedelta_since_post': datetime.timedelta(seconds=19810, microseconds=551805),
#   'time_since_post': '5h30m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363693',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'CSS Animation Made Ease',
#   'timedelta_since_post': datetime.timedelta(seconds=19916, microseconds=747975),
#   'time_since_post': '5h31m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363681',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': "Iran's online taxi service Tapsi breaches 30M people's PII and trip info",
#   'timedelta_since_post': datetime.timedelta(seconds=19927, microseconds=916934),
#   'time_since_post': '5h32m',
#   'comments_per_minute': 0.0030109901139157924,
#   'url': 'https://news.ycombinator.com/item?id=37363678',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 132,
#   'title': 'No way in or out of Burning Man after storm',
#   'timedelta_since_post': datetime.timedelta(seconds=19941, microseconds=338727),
#   'time_since_post': '5h32m',
#   'comments_per_minute': 0.39717165638633967,
#   'url': 'https://news.ycombinator.com/item?id=37363674',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Tips for maintaining small to medium projects with Yocto',
#   'timedelta_since_post': datetime.timedelta(seconds=19956, microseconds=346444),
#   'time_since_post': '5h32m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363671',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Let’s End the Myth That Ideas Are Worthless',
#   'timedelta_since_post': datetime.timedelta(seconds=19964, microseconds=498421),
#   'time_since_post': '5h32m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363669',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'A system to keep cloud-based gamers in sync',
#   'timedelta_since_post': datetime.timedelta(seconds=19997, microseconds=696842),
#   'time_since_post': '5h33m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363665',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Paid Version of Facebook and Instagram May Be Coming to the EU',
#   'timedelta_since_post': datetime.timedelta(seconds=20012, microseconds=885139),
#   'time_since_post': '5h33m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363662',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'At risk from rising seas, Norfolk, VA, plans controversial floodwall',
#   'timedelta_since_post': datetime.timedelta(seconds=20166, microseconds=52101),
#   'time_since_post': '5h36m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363631',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 41,
#   'title': 'In-memory vs. disk-based DB: Why do you need a larger than memory architecture?',
#   'timedelta_since_post': datetime.timedelta(seconds=20242, microseconds=217007),
#   'time_since_post': '5h37m',
#   'comments_per_minute': 0.12152949313308961,
#   'url': 'https://news.ycombinator.com/item?id=37363623',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 158,
#   'title': 'Tax prep companies: $90M lobbying against free tax-filing',
#   'timedelta_since_post': datetime.timedelta(seconds=20263, microseconds=787556),
#   'time_since_post': '5h37m',
#   'comments_per_minute': 0.4678478014114396,
#   'url': 'https://news.ycombinator.com/item?id=37363616',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Dora, SPACE, GSM, or DevEx: How to measure developer productivity?',
#   'timedelta_since_post': datetime.timedelta(seconds=20389, microseconds=49524),
#   'time_since_post': '5h39m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363601',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Jimmy Buffett, Singer Who Turned Island Escapism Into an Empire, Dead at 76',
#   'timedelta_since_post': datetime.timedelta(seconds=20440, microseconds=197455),
#   'time_since_post': '5h40m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363596',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Ex-Wells Fargo Exec Deserves Prison in Accounts Scandal, US Says',
#   'timedelta_since_post': datetime.timedelta(seconds=20448, microseconds=353354),
#   'time_since_post': '5h40m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363595',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Valve rejects Steam games with AI content over copyright concerns',
#   'timedelta_since_post': datetime.timedelta(seconds=20578, microseconds=500041),
#   'time_since_post': '5h42m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363573',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Ukrainian M1 Abrams Tank Crews Complete Training',
#   'timedelta_since_post': datetime.timedelta(seconds=20649, microseconds=672798),
#   'time_since_post': '5h44m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363561',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Russia’s African Coup Strategy',
#   'timedelta_since_post': datetime.timedelta(seconds=20656, microseconds=863835),
#   'time_since_post': '5h44m',
#   'comments_per_minute': 0.0029047250193648335,
#   'url': 'https://news.ycombinator.com/item?id=37363557',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Where is the wealth of nations in the 21st century?',
#   'timedelta_since_post': datetime.timedelta(seconds=20706, microseconds=319772),
#   'time_since_post': '5h45m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363546',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'A brain-inspired algorithm that mitigates catastrophic forgetting of neural nets',
#   'timedelta_since_post': datetime.timedelta(seconds=20780, microseconds=485906),
#   'time_since_post': '5h46m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363526',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 14,
#   'title': 'How to learn work ethics and discipline as an adult?',
#   'timedelta_since_post': datetime.timedelta(seconds=20798, microseconds=665581),
#   'time_since_post': '5h46m',
#   'comments_per_minute': 0.040388498894124436,
#   'url': 'https://news.ycombinator.com/item?id=37363522',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'LibreOffice 7.6 released with a few Firebird fixes for Base',
#   'timedelta_since_post': datetime.timedelta(seconds=20903, microseconds=342614),
#   'time_since_post': '5h48m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363506',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 53,
#   'title': 'Renting vs. Owning a Home, by State',
#   'timedelta_since_post': datetime.timedelta(seconds=20906, microseconds=528456),
#   'time_since_post': '5h48m',
#   'comments_per_minute': 0.15210944226537837,
#   'url': 'https://news.ycombinator.com/item?id=37363505',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Test for Bias After Finetuning LLMs',
#   'timedelta_since_post': datetime.timedelta(seconds=20967, microseconds=533519),
#   'time_since_post': '5h49m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363491',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 62,
#   'title': 'Sorry, Your Paper Coffee Cup Is a Toxic Nightmare',
#   'timedelta_since_post': datetime.timedelta(seconds=21085, microseconds=687135),
#   'time_since_post': '5h51m',
#   'comments_per_minute': 0.17642874081100307,
#   'url': 'https://news.ycombinator.com/item?id=37363468',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Google’s Cloud Next tech conference is leaving San Francisco',
#   'timedelta_since_post': datetime.timedelta(seconds=21225, microseconds=454059),
#   'time_since_post': '5h53m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363445',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Book of the Week – Mushrooms, Russia and History',
#   'timedelta_since_post': datetime.timedelta(seconds=21290, microseconds=622630),
#   'time_since_post': '5h54m',
#   'comments_per_minute': 0.0028182245185533117,
#   'url': 'https://news.ycombinator.com/item?id=37363433',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Why Camera Makers Will Be Dead (Soonish)',
#   'timedelta_since_post': datetime.timedelta(seconds=21406, microseconds=71351),
#   'time_since_post': '5h56m',
#   'comments_per_minute': 0.0028029524432402132,
#   'url': 'https://news.ycombinator.com/item?id=37363410',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Antarctic research stations have polluted a pristine wilderness',
#   'timedelta_since_post': datetime.timedelta(seconds=21483, microseconds=505213),
#   'time_since_post': '5h58m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363394',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 6,
#   'title': 'Show HN: E-commerce store for just $5 a month',
#   'timedelta_since_post': datetime.timedelta(seconds=21530, microseconds=687641),
#   'time_since_post': '5h58m',
#   'comments_per_minute': 0.01672085462145843,
#   'url': 'https://news.ycombinator.com/item?id=37363390',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Prompt engineering for educators – making generative AI work for you',
#   'timedelta_since_post': datetime.timedelta(seconds=21563, microseconds=958461),
#   'time_since_post': '5h59m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363384',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 62,
#   'title': 'Recursively Summarizing Enables Long-Term Dialogue Memory in LLMs',
#   'timedelta_since_post': datetime.timedelta(seconds=21733, microseconds=144040),
#   'time_since_post': '6h2m',
#   'comments_per_minute': 0.17116826945198546,
#   'url': 'https://news.ycombinator.com/item?id=37363362',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 3,
#   'title': 'Don’t you dare rake your leaves this fall – mosquitoes and biodiversity collapse',
#   'timedelta_since_post': datetime.timedelta(seconds=21888, microseconds=186570),
#   'time_since_post': '6h4m',
#   'comments_per_minute': 0.008223684210526315,
#   'url': 'https://news.ycombinator.com/item?id=37363348',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'All-Domain Anomaly Resolution Office (AARO)',
#   'timedelta_since_post': datetime.timedelta(seconds=21972, microseconds=172565),
#   'time_since_post': '6h6m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363337',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': "GitHub started using the company's official Mastodon account",
#   'timedelta_since_post': datetime.timedelta(seconds=21990, microseconds=349664),
#   'time_since_post': '6h6m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363334',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 32,
#   'title': 'College students are struggling with basic math',
#   'timedelta_since_post': datetime.timedelta(seconds=22160, microseconds=520618),
#   'time_since_post': '6h9m',
#   'comments_per_minute': 0.08664259927797835,
#   'url': 'https://news.ycombinator.com/item?id=37363308',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': "Strava, the World's Sweetest Social Network",
#   'timedelta_since_post': datetime.timedelta(seconds=22195, microseconds=902264),
#   'time_since_post': '6h9m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363296',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Nissan Repurposing Leaf Batteries as Portable Power Stations',
#   'timedelta_since_post': datetime.timedelta(seconds=22300, microseconds=91711),
#   'time_since_post': '6h11m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363285',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'A Flawed Comparison: Inequality, Ancient and Modern',
#   'timedelta_since_post': datetime.timedelta(seconds=22491, microseconds=251293),
#   'time_since_post': '6h14m',
#   'comments_per_minute': 0.0026677337601707348,
#   'url': 'https://news.ycombinator.com/item?id=37363255',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Terraforming Singapore: Is the Future Made of Sand?',
#   'timedelta_since_post': datetime.timedelta(seconds=22697, microseconds=690776),
#   'time_since_post': '6h18m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363220',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': "Ask HN: Is there any known reason why Outlook (Web) doesn't on OpenIndiana?",
#   'timedelta_since_post': datetime.timedelta(seconds=22698, microseconds=830372),
#   'time_since_post': '6h18m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363219',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Death on the Savage Mountain: What Happened on K2',
#   'timedelta_since_post': datetime.timedelta(seconds=22841, microseconds=978215),
#   'time_since_post': '6h20m',
#   'comments_per_minute': 0.002626855216496651,
#   'url': 'https://news.ycombinator.com/item?id=37363194',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 2,
#   'title': 'AI-discovered drugs will be for sale soon',
#   'timedelta_since_post': datetime.timedelta(seconds=22922, microseconds=427085),
#   'time_since_post': '6h22m',
#   'comments_per_minute': 0.005235145275281389,
#   'url': 'https://news.ycombinator.com/item?id=37363181',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'On the Acoustics of Cocktail Parties',
#   'timedelta_since_post': datetime.timedelta(seconds=22931, microseconds=161495),
#   'time_since_post': '6h22m',
#   'comments_per_minute': 0.002616545288038027,
#   'url': 'https://news.ycombinator.com/item?id=37363178',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Microprocessors Are Tiny, but They Can’t Fit in Your Head',
#   'timedelta_since_post': datetime.timedelta(seconds=23160, microseconds=609889),
#   'time_since_post': '6h26m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37363141',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 11,
#   'title': 'ZimaBlade: A single-board x86 personal server for cyber natives',
#   'timedelta_since_post': datetime.timedelta(seconds=23283, microseconds=789030),
#   'time_since_post': '6h28m',
#   'comments_per_minute': 0.028346862517716787,
#   'url': 'https://news.ycombinator.com/item?id=37363125',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Generative AI in Jupyter',
#   'timedelta_since_post': datetime.timedelta(seconds=23365, microseconds=558002),
#   'time_since_post': '6h29m',
#   'comments_per_minute': 0.0025679435052428845,
#   'url': 'https://news.ycombinator.com/item?id=37363113',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
# ...
#   'timedelta_since_post': datetime.timedelta(seconds=61288, microseconds=725098),
#   'time_since_post': '17h1m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358968',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Extreme brainstorming questions to trigger new, better ideas (2022)',
#   'timedelta_since_post': datetime.timedelta(seconds=61348, microseconds=916245),
#   'time_since_post': '17h2m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358962',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': '[deleted]',
#   'timedelta_since_post': datetime.timedelta(seconds=61629, microseconds=69553),
#   'time_since_post': '17h7m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358946',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Musk’s changes at Twitter helped spread Russian propaganda, EU study finds',
#   'timedelta_since_post': datetime.timedelta(seconds=61750, microseconds=240792),
#   'time_since_post': '17h9m',
#   'comments_per_minute': 0.00097165991902834,
#   'url': 'https://news.ycombinator.com/item?id=37358933',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Like GeoGuessr, but for Videogames',
#   'timedelta_since_post': datetime.timedelta(seconds=61759, microseconds=702651),
#   'time_since_post': '17h9m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358932',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'What needs to be changed with OSS monetization model',
#   'timedelta_since_post': datetime.timedelta(seconds=61832, microseconds=917668),
#   'time_since_post': '17h10m',
#   'comments_per_minute': 0.0009703713287618062,
#   'url': 'https://news.ycombinator.com/item?id=37358925',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'The Rome tools project is officially discontinued',
#   'timedelta_since_post': datetime.timedelta(seconds=61873, microseconds=649056),
#   'time_since_post': '17h11m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358920',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Marcelito Pomoy',
#   'timedelta_since_post': datetime.timedelta(seconds=62421, microseconds=806861),
#   'time_since_post': '17h20m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358892',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Bypass Two-Factor Authentication of Facebook Accounts ($25,300)',
#   'timedelta_since_post': datetime.timedelta(seconds=62434, microseconds=965004),
#   'time_since_post': '17h20m',
#   'comments_per_minute': 0.0009610148316622353,
#   'url': 'https://news.ycombinator.com/item?id=37358889',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Gravity and dark matter, a bond beyond distances',
#   'timedelta_since_post': datetime.timedelta(seconds=62466, microseconds=424934),
#   'time_since_post': '17h21m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358888',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Learn OpenGL',
#   'timedelta_since_post': datetime.timedelta(seconds=62482, microseconds=588542),
#   'time_since_post': '17h21m',
#   'comments_per_minute': 0.000960276559649179,
#   'url': 'https://news.ycombinator.com/item?id=37358884',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': "Britain's Great Tax Con",
#   'timedelta_since_post': datetime.timedelta(seconds=62550, microseconds=986377),
#   'time_since_post': '17h22m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358880',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'The Future of Appalachia',
#   'timedelta_since_post': datetime.timedelta(seconds=62592, microseconds=185158),
#   'time_since_post': '17h23m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358877',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Collecting Prometheus metrics from multi-process web servers, the Ruby case',
#   'timedelta_since_post': datetime.timedelta(seconds=62833, microseconds=365738),
#   'time_since_post': '17h27m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358858',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'The Official Guide to Learning OpenGL, Version 1.1 (1997)',
#   'timedelta_since_post': datetime.timedelta(seconds=63019, microseconds=525155),
#   'time_since_post': '17h30m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358839',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Fractional Calculus',
#   'timedelta_since_post': datetime.timedelta(seconds=63406, microseconds=681128),
#   'time_since_post': '17h36m',
#   'comments_per_minute': 0.0009462826861811185,
#   'url': 'https://news.ycombinator.com/item?id=37358813',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Live Launch of PSLV-C57/Aditya-L1 Solar Mission [video]',
#   'timedelta_since_post': datetime.timedelta(seconds=63591, microseconds=126688),
#   'time_since_post': '17h39m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358799',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Velcro in OpenScad',
#   'timedelta_since_post': datetime.timedelta(seconds=63592, microseconds=298344),
#   'time_since_post': '17h39m',
#   'comments_per_minute': 0.0009435149075355391,
#   'url': 'https://news.ycombinator.com/item?id=37358798',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Mercedes CLA concept to bring new look and 466-mile range',
#   'timedelta_since_post': datetime.timedelta(seconds=63956, microseconds=743517),
#   'time_since_post': '17h45m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358774',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'The Halloween Problem',
#   'timedelta_since_post': datetime.timedelta(seconds=63991, microseconds=912380),
#   'time_since_post': '17h46m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358770',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Show HN: ClickPaw – A macOS auto-clicker app with image targeting',
#   'timedelta_since_post': datetime.timedelta(seconds=65215, microseconds=109334),
#   'time_since_post': '18h6m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358692',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Playing Sonic the Hedgehog 2 Using Deep Learning',
#   'timedelta_since_post': datetime.timedelta(seconds=65364, microseconds=264980),
#   'time_since_post': '18h9m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358683',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'AIGC Tutorials curates content on AIGC for all AI enthusiasts',
#   'timedelta_since_post': datetime.timedelta(seconds=65382, microseconds=457852),
#   'time_since_post': '18h9m',
#   'comments_per_minute': 0.0009176837661741764,
#   'url': 'https://news.ycombinator.com/item?id=37358680',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 3,
#   'title': 'AdaCore Announces Gnat Pro for Rust',
#   'timedelta_since_post': datetime.timedelta(seconds=65631, microseconds=889845),
#   'time_since_post': '18h13m',
#   'comments_per_minute': 0.0027426063902728894,
#   'url': 'https://news.ycombinator.com/item?id=37358673',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Knowledge Is Sanity',
#   'timedelta_since_post': datetime.timedelta(seconds=66335, microseconds=474561),
#   'time_since_post': '18h25m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358638',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Blue-Green Consul Deployment: Samples in PHP, Java and Node.js',
#   'timedelta_since_post': datetime.timedelta(seconds=66362, microseconds=677482),
#   'time_since_post': '18h26m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358637',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 2,
#   'title': '3b1B: The origin of light, scattering, and polarization [video]',
#   'timedelta_since_post': datetime.timedelta(seconds=66412, microseconds=841925),
#   'time_since_post': '18h26m',
#   'comments_per_minute': 0.001806902367042101,
#   'url': 'https://news.ycombinator.com/item?id=37358633',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 2,
#   'title': 'ESP32 NodeMCU alternative for enterprise projects',
#   'timedelta_since_post': datetime.timedelta(seconds=67341, microseconds=316946),
#   'time_since_post': '18h42m',
#   'comments_per_minute': 0.001781975319641823,
#   'url': 'https://news.ycombinator.com/item?id=37358588',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 18,
#   'title': 'The tensor product, demystified (2018)',
#   'timedelta_since_post': datetime.timedelta(seconds=67519, microseconds=41041),
#   'time_since_post': '18h45m',
#   'comments_per_minute': 0.01599549756364875,
#   'url': 'https://news.ycombinator.com/item?id=37358577',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Scs Cloud Conference_Dr. Anton_Speech_01 [video]',
#   'timedelta_since_post': datetime.timedelta(seconds=67691, microseconds=159263),
#   'time_since_post': '18h48m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358565',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': "Onsen: The history, science, and business of Japan's hot springs [Longform]",
#   'timedelta_since_post': datetime.timedelta(seconds=67744, microseconds=330414),
#   'time_since_post': '18h49m',
#   'comments_per_minute': 0.0008856872933396316,
#   'url': 'https://news.ycombinator.com/item?id=37358558',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 3,
#   'title': 'Hermeneutic phenomonology and differential testing [pdf]',
#   'timedelta_since_post': datetime.timedelta(seconds=68032, microseconds=781525),
#   'time_since_post': '18h53m',
#   'comments_per_minute': 0.0026458137347130763,
#   'url': 'https://news.ycombinator.com/item?id=37358544',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 40,
#   'title': 'Invariants: A Better Debugger?',
#   'timedelta_since_post': datetime.timedelta(seconds=68073, microseconds=366793),
#   'time_since_post': '18h54m',
#   'comments_per_minute': 0.03525626900533251,
#   'url': 'https://news.ycombinator.com/item?id=37358541',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'SuperMemo for Wizards [video]',
#   'timedelta_since_post': datetime.timedelta(seconds=68451, microseconds=752765),
#   'time_since_post': '19h0m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358520',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 1,
#   'title': 'Hypatia transracialism controversy',
#   'timedelta_since_post': datetime.timedelta(seconds=68571, microseconds=928753),
#   'time_since_post': '19h2m',
#   'comments_per_minute': 0.00087500546878418,
#   'url': 'https://news.ycombinator.com/item?id=37358517',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 14,
#   'title': 'WAPO: Fatal Force DB',
#   'timedelta_since_post': datetime.timedelta(seconds=68738, microseconds=719160),
#   'time_since_post': '19h5m',
#   'comments_per_minute': 0.012220314818586516,
#   'url': 'https://news.ycombinator.com/item?id=37358508',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 5,
#   'title': 'How to protect your ears and avoid hearing loss: An illustrated guide',
#   'timedelta_since_post': datetime.timedelta(seconds=68965, microseconds=962582),
#   'time_since_post': '19h9m',
#   'comments_per_minute': 0.004350032625244689,
#   'url': 'https://news.ycombinator.com/item?id=37358498',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Local LLM inference GPU coil whine [video]',
#   'timedelta_since_post': datetime.timedelta(seconds=69181, microseconds=205528),
#   'time_since_post': '19h13m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358482',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Ask HN: Misquoting of Search Result Numbers',
#   'timedelta_since_post': datetime.timedelta(seconds=69190, microseconds=387181),
#   'time_since_post': '19h13m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358480',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 9,
#   'title': 'The Craft of Experimental Physics (2015)',
#   'timedelta_since_post': datetime.timedelta(seconds=69441, microseconds=568769),
#   'time_since_post': '19h17m',
#   'comments_per_minute': 0.007776385708731154,
#   'url': 'https://news.ycombinator.com/item?id=37358468',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 4,
#   'title': 'Ask HN: Why does the Clojure ecosystem feel like such a wasteland?',
#   'timedelta_since_post': datetime.timedelta(seconds=69805, microseconds=602288),
#   'time_since_post': '19h23m',
#   'comments_per_minute': 0.0034381491297185013,
#   'url': 'https://news.ycombinator.com/item?id=37358446',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'FlagLookup: Search flags based on color or design',
#   'timedelta_since_post': datetime.timedelta(seconds=69993, microseconds=323611),
#   'time_since_post': '19h26m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358428',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Validating Security Boundaries in AWS Firecracker',
#   'timedelta_since_post': datetime.timedelta(seconds=70194, microseconds=488662),
#   'time_since_post': '19h29m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358415',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Explaining the Postgres Meme',
#   'timedelta_since_post': datetime.timedelta(seconds=70230, microseconds=714784),
#   'time_since_post': '19h30m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358412',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0},
#  {'num_comments': 0,
#   'title': 'Old meets new: hybrid search',
#   'timedelta_since_post': datetime.timedelta(seconds=70420, microseconds=883921),
#   'time_since_post': '19h33m',
#   'comments_per_minute': 0.0,
#   'url': 'https://news.ycombinator.com/item?id=37358402',
#   'recent_comment_velocity': 0,
#   'recent_comments_per_minute': 0}]
