# %%
import requests as r
import time
from datetime import datetime
from datetime import timedelta
import pandas as pd

'''
All HN API requests are constructed using the following reference: https://github.com/HackerNews/API
'''

base_url = "https://hacker-news.firebaseio.com/v0/"
human_display_item_url = "https://news.ycombinator.com/item?id="
new_stories_slug = "newstories"
item_slug = "item/"
json_append_slug = ".json"

# %%
### Get Story IDs for the newest stories from the HN New Stories endpoint
new_stories_response = r.get(base_url + new_stories_slug + json_append_slug)
new_stories_json = new_stories_response.json()

# %%
# returns datetime.timedelta object representing time between execution and story posting
def get_td_from_story(story):
    story_unix_time = story['time']
    story_datetime = datetime.fromtimestamp(story_unix_time)
    timedelta_since_post = datetime.now() - story_datetime
    return timedelta_since_post

def get_comments_per_minute_from_story(timedelta_since_post, num_comments):
    minutes_since_post = timedelta_since_post.seconds / 60
    comments_per_minute = (num_comments * 1.0) / minutes_since_post
    return comments_per_minute

def format_timedelta(timedelta_since_post):
    hours_since_post, remainder = divmod(timedelta_since_post.seconds, 3600)
    minutes_since_post, seconds = divmod(remainder, 60)
    time_since_post = str(hours_since_post) + 'h' + str(minutes_since_post) + 'm'
    return time_since_post

def get_comment_timestamps(story_json, delay_in_seconds):
    comments = story_json['kids']
    comment_timestamps = []
    for comment_id in comments:
        comment_response = r.get(base_url + item_slug + str(comment_id) + json_append_slug)
        comment = comment_response.json()
        comment_timestamps.append(comment['time'])
        time.sleep(delay_in_seconds)
    return comment_timestamps

def get_item_timestamps_for_all_kids(item_json, delay_in_seconds):
    if 'kids' not in item_json:
        return []
    kids = item_json['kids']
    print("Pulling timestamp info of kids for item with " + str(len(kids)) + " kids")
    kid_timestamps = []
    for kid_id in kids:
        kid_response = r.get(base_url + item_slug + str(kid_id) + json_append_slug)
        kid_json = kid_response.json()
        kid_timestamps.append(kid_json['time'])
        kid_timestamps = kid_timestamps + get_item_timestamps_for_all_kids(kid_json, delay_in_seconds)
        time.sleep(delay_in_seconds)
    return kid_timestamps

# Structure: story_id: {num_comments, }
story_info_tracker = {}
num_stories = len(new_stories_json)
comment_timeseries_records = []
for i, story_id in enumerate(new_stories_json):
    story_response = r.get(base_url + item_slug + str(story_id) + json_append_slug)
    story = story_response.json()
    if 'descendants' in story:
        num_comments = story['descendants']
    elif ('dead' in story and story['dead']):
        continue
    elif ('deleted' in story and story['deleted']):
        continue
    else:
        raise Exception("Couldn't find descendants in story: " + str(story))
    title = story['title']

    story_unix_time = story['time']
    story_datetime = datetime.fromtimestamp(story_unix_time)
    
    timedelta_since_post = get_td_from_story(story)
    comments_per_minute = get_comments_per_minute_from_story(timedelta_since_post, num_comments)
    time_since_post = format_timedelta(timedelta_since_post)
    if num_comments > 0:
        item_timestamps = get_item_timestamps_for_all_kids(story, 0.1)
    else:
        item_timestamps = []
    for timestamp in item_timestamps:
        comment_timeseries_records.append({'story_id': story_id, 
                                           'story_title': title,
                                           'comment_timestamp': datetime.fromtimestamp(timestamp)})
    story_info_tracker[story_id] = {
        'story_id': story_id,
        'num_comments': num_comments,
        'title': title,
        'timedelta_since_post': timedelta_since_post,
        'time_since_post': time_since_post,
        'comments_per_minute': comments_per_minute,
        'story_datetime': story_datetime,
        'url': human_display_item_url + str(story_id),
        'comment_timestamps': item_timestamps,
    }
    print("Pulled info for story " + str(i) + "/" + str(num_stories))
# Out:
# Pulled info for story 0/500
# Pulled info for story 1/500
# Pulled info for story 2/500
# Pulled info for story 3/500
# Pulled info for story 4/500
# Pulled info for story 5/500
# Pulled info for story 6/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 7/500
# Pulled info for story 8/500
# Pulled info for story 9/500
# Pulled info for story 10/500
# Pulled info for story 11/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 12/500
# Pulled info for story 13/500
# Pulled info for story 14/500
# Pulled info for story 15/500
# Pulled info for story 16/500
# Pulled info for story 17/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 18/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 19/500
# Pulled info for story 20/500
# Pulled info for story 21/500
# Pulled info for story 22/500
# Pulled info for story 23/500
# Pulled info for story 24/500
# Pulled info for story 25/500
# Pulled info for story 26/500
# Pulled info for story 27/500
# Pulled info for story 28/500
# Pulled info for story 29/500
# Pulled info for story 30/500
# Pulled info for story 31/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 32/500
# Pulled info for story 33/500
# Pulled info for story 34/500
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 35/500
# Pulled info for story 36/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 37/500
# Pulled info for story 38/500
# Pulling timestamp info of kids for item with 14 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 39/500
# Pulled info for story 40/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 41/500
# Pulled info for story 42/500
# Pulled info for story 43/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 44/500
# Pulled info for story 45/500
# Pulled info for story 46/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 47/500
# Pulled info for story 48/500
# Pulled info for story 49/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 50/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 51/500
# Pulled info for story 52/500
# Pulled info for story 53/500
# Pulled info for story 54/500
# Pulled info for story 55/500
# Pulled info for story 56/500
# Pulled info for story 57/500
# Pulling timestamp info of kids for item with 15 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 58/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 59/500
# Pulled info for story 60/500
# Pulled info for story 61/500
# Pulled info for story 62/500
# Pulled info for story 63/500
# Pulling timestamp info of kids for item with 3 kids
# Pulled info for story 64/500
# Pulled info for story 65/500
# Pulling timestamp info of kids for item with 3 kids
# Pulled info for story 66/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 67/500
# Pulled info for story 68/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 69/500
# Pulled info for story 70/500
# Pulled info for story 71/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 72/500
# Pulled info for story 73/500
# Pulled info for story 74/500
# Pulled info for story 75/500
# Pulling timestamp info of kids for item with 10 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 76/500
# Pulled info for story 77/500
# Pulled info for story 78/500
# Pulling timestamp info of kids for item with 3 kids
# Pulled info for story 79/500
# Pulled info for story 80/500
# Pulled info for story 81/500
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 82/500
# Pulled info for story 83/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 84/500
# Pulled info for story 85/500
# Pulled info for story 86/500
# Pulled info for story 87/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 88/500
# Pulled info for story 89/500
# Pulled info for story 90/500
# Pulled info for story 91/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 92/500
# Pulled info for story 93/500
# Pulled info for story 94/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 95/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 96/500
# Pulled info for story 97/500
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 98/500
# Pulled info for story 99/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 100/500
# Pulled info for story 101/500
# Pulled info for story 102/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 103/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 104/500
# Pulled info for story 105/500
# Pulled info for story 106/500
# Pulled info for story 107/500
# Pulled info for story 108/500
# Pulled info for story 109/500
# Pulled info for story 110/500
# Pulled info for story 111/500
# Pulled info for story 112/500
# Pulled info for story 113/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 114/500
# Pulled info for story 115/500
# Pulled info for story 116/500
# Pulled info for story 117/500
# Pulled info for story 118/500
# Pulled info for story 119/500
# Pulling timestamp info of kids for item with 3 kids
# Pulled info for story 120/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 121/500
# Pulled info for story 122/500
# Pulled info for story 123/500
# Pulled info for story 124/500
# Pulled info for story 125/500
# Pulled info for story 126/500
# Pulling timestamp info of kids for item with 23 kids
# Pulling timestamp info of kids for item with 10 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulled info for story 127/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 128/500
# Pulled info for story 129/500
# Pulled info for story 130/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 131/500
# Pulled info for story 132/500
# Pulled info for story 133/500
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 134/500
# Pulled info for story 135/500
# Pulled info for story 136/500
# Pulled info for story 137/500
# Pulled info for story 138/500
# Pulled info for story 139/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 140/500
# Pulling timestamp info of kids for item with 9 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 141/500
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 142/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 143/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 144/500
# Pulled info for story 145/500
# Pulling timestamp info of kids for item with 14 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 146/500
# Pulled info for story 147/500
# Pulled info for story 148/500
# Pulled info for story 149/500
# Pulled info for story 150/500
# Pulling timestamp info of kids for item with 4 kids
# Pulled info for story 151/500
# Pulled info for story 152/500
# Pulled info for story 153/500
# Pulled info for story 154/500
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 155/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 156/500
# Pulling timestamp info of kids for item with 11 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 157/500
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 158/500
# Pulled info for story 159/500
# Pulling timestamp info of kids for item with 19 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 8 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 160/500
# Pulled info for story 161/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 162/500
# Pulled info for story 163/500
# Pulled info for story 164/500
# Pulled info for story 165/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 166/500
# Pulled info for story 167/500
# Pulled info for story 168/500
# Pulled info for story 169/500
# Pulled info for story 170/500
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 171/500
# Pulling timestamp info of kids for item with 11 kids
# Pulling timestamp info of kids for item with 11 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 172/500
# Pulled info for story 173/500
# Pulled info for story 174/500
# Pulled info for story 175/500
# Pulled info for story 176/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 177/500
# Pulled info for story 178/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 179/500
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 180/500
# Pulled info for story 181/500
# Pulled info for story 182/500
# Pulled info for story 183/500
# Pulling timestamp info of kids for item with 10 kids
# Pulling timestamp info of kids for item with 11 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 184/500
# Pulled info for story 185/500
# Pulled info for story 186/500
# Pulled info for story 187/500
# Pulled info for story 188/500
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 189/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 190/500
# Pulled info for story 191/500
# Pulled info for story 192/500
# Pulled info for story 193/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 194/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 195/500
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 196/500
# Pulled info for story 197/500
# Pulled info for story 198/500
# Pulled info for story 199/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 200/500
# Pulling timestamp info of kids for item with 3 kids
# Pulled info for story 201/500
# Pulled info for story 202/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 203/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 204/500
# Pulled info for story 205/500
# Pulled info for story 206/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 207/500
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 208/500
# Pulled info for story 209/500
# Pulled info for story 210/500
# Pulled info for story 211/500
# Pulled info for story 212/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 213/500
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 214/500
# Pulled info for story 215/500
# Pulled info for story 216/500
# Pulled info for story 217/500
# Pulled info for story 218/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 219/500
# Pulled info for story 220/500
# Pulled info for story 221/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 222/500
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 223/500
# Pulled info for story 224/500
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 225/500
# Pulled info for story 226/500
# Pulling timestamp info of kids for item with 4 kids
# Pulled info for story 227/500
# Pulled info for story 228/500
# Pulled info for story 229/500
# Pulled info for story 230/500
# Pulled info for story 231/500
# Pulled info for story 232/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 233/500
# Pulling timestamp info of kids for item with 3 kids
# Pulled info for story 234/500
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 235/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 236/500
# Pulled info for story 237/500
# Pulled info for story 238/500
# Pulling timestamp info of kids for item with 3 kids
# Pulled info for story 239/500
# Pulled info for story 240/500
# Pulled info for story 241/500
# Pulled info for story 242/500
# Pulled info for story 243/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 244/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 245/500
# Pulled info for story 246/500
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 247/500
# Pulled info for story 248/500
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 249/500
# Pulling timestamp info of kids for item with 14 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 250/500
# Pulled info for story 251/500
# Pulled info for story 252/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 253/500
# Pulling timestamp info of kids for item with 13 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 254/500
# Pulled info for story 255/500
# Pulled info for story 256/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 257/500
# Pulling timestamp info of kids for item with 10 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 258/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 259/500
# Pulled info for story 260/500
# Pulling timestamp info of kids for item with 17 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 261/500
# Pulled info for story 262/500
# Pulling timestamp info of kids for item with 10 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 263/500
# Pulling timestamp info of kids for item with 11 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 264/500
# Pulled info for story 265/500
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 266/500
# Pulled info for story 267/500
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 268/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 269/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 270/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 271/500
# Pulled info for story 272/500
# Pulled info for story 273/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 274/500
# Pulled info for story 275/500
# Pulled info for story 276/500
# Pulling timestamp info of kids for item with 42 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 7 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 9 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 7 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 277/500
# Pulling timestamp info of kids for item with 23 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 278/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 279/500
# Pulled info for story 280/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 281/500
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 282/500
# Pulling timestamp info of kids for item with 15 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 283/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 284/500
# Pulled info for story 285/500
# Pulled info for story 286/500
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 287/500
# Pulled info for story 288/500
# Pulled info for story 289/500
# Pulled info for story 290/500
# Pulled info for story 291/500
# Pulling timestamp info of kids for item with 19 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 10 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 292/500
# Pulled info for story 293/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 294/500
# Pulled info for story 295/500
# Pulled info for story 296/500
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 297/500
# Pulled info for story 298/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 299/500
# Pulled info for story 300/500
# Pulling timestamp info of kids for item with 8 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 301/500
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 302/500
# Pulled info for story 303/500
# Pulling timestamp info of kids for item with 21 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 304/500
# Pulling timestamp info of kids for item with 10 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 305/500
# Pulled info for story 306/500
# Pulled info for story 307/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 308/500
# Pulled info for story 309/500
# Pulled info for story 310/500
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# ...
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 8 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulled info for story 474/500
# Pulled info for story 475/500
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 476/500
# Pulling timestamp info of kids for item with 2 kids
# Pulled info for story 477/500
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 478/500
# Pulled info for story 479/500
# Pulled info for story 480/500
# Pulled info for story 481/500
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 482/500
# Pulled info for story 483/500
# Pulled info for story 484/500
# Pulled info for story 485/500
# Pulled info for story 486/500
# Pulled info for story 487/500
# Pulling timestamp info of kids for item with 19 kids
# Pulling timestamp info of kids for item with 11 kids
# Pulling timestamp info of kids for item with 7 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 16 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 488/500
# Pulled info for story 489/500
# Pulled info for story 490/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 491/500
# Pulling timestamp info of kids for item with 37 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 5 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulled info for story 492/500
# Pulling timestamp info of kids for item with 1 kids
# Pulled info for story 493/500
# Pulled info for story 494/500
# Pulling timestamp info of kids for item with 26 kids
# Pulling timestamp info of kids for item with 9 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 7 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 6 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 3 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 1 kids
# Pulling timestamp info of kids for item with 2 kids
# Pulling timestamp info of kids for item with 4 kids
# Pulled info for story 495/500
# Pulled info for story 496/500
# Pulled info for story 497/500
# Pulled info for story 498/500
# Pulled info for story 499/500

# %%
comment_timeseries_df = pd.DataFrame.from_records(comment_timeseries_records)

comment_timeseries_df.to_csv('comment_timeseries_df.csv')

# %%
# Gets comments per minute from an array of unix timestamps representing comment times, and minutes in the past to consider recent.
def get_comments_per_minute_from_recent_comments(comment_unix_timestamp_array, minutes_to_consider_recent):
    recency_datetime = datetime.now() - timedelta(minutes=minutes_to_consider_recent)
    filtered_comments = [comment for comment in comment_unix_timestamp_array if comment >= recency_datetime.timestamp()]
    filtered_comments_sorted = sorted(filtered_comments)
    if len(filtered_comments_sorted) <= 1:
        return 0
    first_comment_timestamp = datetime.fromtimestamp(filtered_comments_sorted[0])
    last_comment_timestamp = datetime.fromtimestamp(filtered_comments_sorted[-1])
    timedelta_between_first_last_comment = last_comment_timestamp - first_comment_timestamp
    minutes_between_first_last_comment = (timedelta_between_first_last_comment.seconds * 1.0) / 60
    return (len(comment_unix_timestamp_array) * 1.0) / minutes_between_first_last_comment

def get_stories_with_recent_comment_velocity(stories, recency_in_minutes):
    stories_with_recent_comment_velocity = {}
    for story_id, story in stories.items():
        recent_comment_velocity = get_comments_per_minute_from_recent_comments(story['comment_timestamps'], recency_in_minutes)
        story['recent_comments_per_minute'] = recent_comment_velocity
        stories_with_recent_comment_velocity[story_id] = story
    return stories_with_recent_comment_velocity

def convert_sorted_stories_to_display_list(sorted_stories):
    original_list = [sorted_story[1] for sorted_story in sorted_stories]
    display_list = []
    for story in original_list:
        display_story = story.copy()
        if 'comment_timestamps' in display_story:
            del display_story['comment_timestamps']
        display_list.append(display_story)
    return display_list

def get_recent(sorted_stories_display_list, minutes_to_consider_recent):
    return [sorted_story for sorted_story in sorted_stories_display_list \
            if (sorted_story['timedelta_since_post'].seconds / 60) < minutes_to_consider_recent]


###
###
###

## EDIT THIS TO CHANGE DEFINITION OF "RECENT COMMENT"
MINUTES_TO_CONSIDER_RECENT = 120


###
###
###

## SORT AND FORMAT STORIES BY RELEVANT METRICS

story_info_tracker = get_stories_with_recent_comment_velocity(story_info_tracker, MINUTES_TO_CONSIDER_RECENT)

num_comments_sorted_stories = sorted(story_info_tracker.items(), key=lambda x: x[1]['num_comments'], reverse=True)
comment_velocity_sorted_stories = sorted(story_info_tracker.items(), key=lambda x: x[1]['comments_per_minute'], reverse=True)
recent_comment_velocity_sorted_stories = sorted(story_info_tracker.items(), key=lambda x: x[1]['recent_comments_per_minute'], reverse=True)

num_comments_sorted_stories_display = convert_sorted_stories_to_display_list(num_comments_sorted_stories)
comment_velocity_sorted_stories_display = convert_sorted_stories_to_display_list(comment_velocity_sorted_stories)
recent_comment_velocity_sorted_stories_display = convert_sorted_stories_to_display_list(recent_comment_velocity_sorted_stories)

# %%
# get_recent(comment_velocity_sorted_stories_display, (3 * 60))
# get_recent(num_comments_sorted_stories_display, (3*60))

# recent_comment_velocity_sorted_stories_display

get_recent(comment_velocity_sorted_stories_display, (6 * 60))
# Out:
# [{'story_id': 37379534,
#   'num_comments': 56,
#   'title': 'Reddit faces content quality concerns after its Great Mod Purge',
#   'timedelta_since_post': datetime.timedelta(seconds=6760, microseconds=436283),
#   'time_since_post': '1h52m',
#   'comments_per_minute': 0.4970414201183432,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 41, 30),
#   'url': 'https://news.ycombinator.com/item?id=37379534',
#   'recent_comments_per_minute': 0.6939003917179631},
#  {'story_id': 37379801,
#   'num_comments': 32,
#   'title': 'I built a Plane Spotter in 120 secs with ChatGPT',
#   'timedelta_since_post': datetime.timedelta(seconds=4219, microseconds=7076),
#   'time_since_post': '1h10m',
#   'comments_per_minute': 0.4550841431618867,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 23, 38),
#   'url': 'https://news.ycombinator.com/item?id=37379801',
#   'recent_comments_per_minute': 1.1592505854800939},
#  {'story_id': 37379272,
#   'num_comments': 52,
#   'title': 'TV Museum Will Die in 48 Hours Unless Sony Retracts YouTube Copyright Strikes',
#   'timedelta_since_post': datetime.timedelta(seconds=9143, microseconds=449544),
#   'time_since_post': '2h32m',
#   'comments_per_minute': 0.3412446680520617,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 2, 11),
#   'url': 'https://news.ycombinator.com/item?id=37379272',
#   'recent_comments_per_minute': 0.5649520488230166},
#  {'story_id': 37378669,
#   'num_comments': 80,
#   'title': 'The curl-wget Venn diagram',
#   'timedelta_since_post': datetime.timedelta(seconds=15204, microseconds=294482),
#   'time_since_post': '4h13m',
#   'comments_per_minute': 0.31570639305445936,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 21, 38),
#   'url': 'https://news.ycombinator.com/item?id=37378669',
#   'recent_comments_per_minute': 0.8969398522687302},
#  {'story_id': 37378179,
#   'num_comments': 56,
#   'title': 'Plastic Money',
#   'timedelta_since_post': datetime.timedelta(seconds=20519, microseconds=364862),
#   'time_since_post': '5h41m',
#   'comments_per_minute': 0.16375067011062916,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 54, 16),
#   'url': 'https://news.ycombinator.com/item?id=37378179',
#   'recent_comments_per_minute': 0.696713245424129},
#  {'story_id': 37378328,
#   'num_comments': 43,
#   'title': 'David Tolnay on the "RustConf Keynote Fiasco"',
#   'timedelta_since_post': datetime.timedelta(seconds=19084, microseconds=99060),
#   'time_since_post': '5h18m',
#   'comments_per_minute': 0.1351917836931461,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 17, 40),
#   'url': 'https://news.ycombinator.com/item?id=37378328',
#   'recent_comments_per_minute': 0.558252427184466},
#  {'story_id': 37378385,
#   'num_comments': 34,
#   'title': 'Cuber: Deploy your apps on Kubernetes easily',
#   'timedelta_since_post': datetime.timedelta(seconds=18612, microseconds=682603),
#   'time_since_post': '5h10m',
#   'comments_per_minute': 0.10960670535138621,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 25, 20),
#   'url': 'https://news.ycombinator.com/item?id=37378385',
#   'recent_comments_per_minute': 0.3612537630600319},
#  {'story_id': 37378196,
#   'num_comments': 28,
#   'title': 'War games: Battlefield strategy and the game of chess',
#   'timedelta_since_post': datetime.timedelta(seconds=20382, microseconds=375954),
#   'time_since_post': '5h39m',
#   'comments_per_minute': 0.08242566970856638,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 56, 24),
#   'url': 'https://news.ycombinator.com/item?id=37378196',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380211,
#   'num_comments': 1,
#   'title': 'AI-Based Meal Plan Generator. Custom-tailored personal meal plans in 60 seconds',
#   'timedelta_since_post': datetime.timedelta(seconds=831, microseconds=370643),
#   'time_since_post': '0h13m',
#   'comments_per_minute': 0.07220216606498195,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 19, 58),
#   'url': 'https://news.ycombinator.com/item?id=37380211',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378450,
#   'num_comments': 17,
#   'title': 'Hardware Random Bit Generator',
#   'timedelta_since_post': datetime.timedelta(seconds=17794, microseconds=256161),
#   'time_since_post': '4h56m',
#   'comments_per_minute': 0.05732269304259863,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 38, 52),
#   'url': 'https://news.ycombinator.com/item?id=37378450',
#   'recent_comments_per_minute': 0.6708074534161491},
#  {'story_id': 37380148,
#   'num_comments': 1,
#   'title': "ELI5: Why does boiling in water make things soft but in oil it's crispy?",
#   'timedelta_since_post': datetime.timedelta(seconds=1267, microseconds=435870),
#   'time_since_post': '0h21m',
#   'comments_per_minute': 0.0473559589581689,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 12, 43),
#   'url': 'https://news.ycombinator.com/item?id=37380148',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380085,
#   'num_comments': 1,
#   'title': 'Saudi Arabia Dangling Billions for Aging Research. Scientists Lining Up for It.',
#   'timedelta_since_post': datetime.timedelta(seconds=1931, microseconds=616648),
#   'time_since_post': '0h32m',
#   'comments_per_minute': 0.03107198342827551,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 1, 40),
#   'url': 'https://news.ycombinator.com/item?id=37380085',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380074,
#   'num_comments': 1,
#   'title': 'Ask HN: Best resource to learn parallel/concurrent programming?',
#   'timedelta_since_post': datetime.timedelta(seconds=2003, microseconds=11967),
#   'time_since_post': '0h33m',
#   'comments_per_minute': 0.029955067398901646,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 0, 29),
#   'url': 'https://news.ycombinator.com/item?id=37380074',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379425,
#   'num_comments': 3,
#   'title': 'Ask HN: Thoughts on Gnu Taler?',
#   'timedelta_since_post': datetime.timedelta(seconds=7794, microseconds=672295),
#   'time_since_post': '2h9m',
#   'comments_per_minute': 0.023094688221709007,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 24, 35),
#   'url': 'https://news.ycombinator.com/item?id=37379425',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379355,
#   'num_comments': 3,
#   'title': 'Ask HN: Reducing Meeting Overload',
#   'timedelta_since_post': datetime.timedelta(seconds=8372, microseconds=819200),
#   'time_since_post': '2h19m',
#   'comments_per_minute': 0.02150023889154324,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 14, 58),
#   'url': 'https://news.ycombinator.com/item?id=37379355',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379242,
#   'num_comments': 3,
#   'title': 'The vertical farming boom is over (for now). What went wrong?',
#   'timedelta_since_post': datetime.timedelta(seconds=9448, microseconds=583824),
#   'time_since_post': '2h37m',
#   'comments_per_minute': 0.019051651143099067,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 57, 20),
#   'url': 'https://news.ycombinator.com/item?id=37379242',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379891,
#   'num_comments': 1,
#   'title': 'Feature Development Chronicles: Challenges, Pivots, and Success',
#   'timedelta_since_post': datetime.timedelta(seconds=3555, microseconds=219507),
#   'time_since_post': '0h59m',
#   'comments_per_minute': 0.016877637130801686,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 34, 39),
#   'url': 'https://news.ycombinator.com/item?id=37379891',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378357,
#   'num_comments': 5,
#   'title': "France's waning influence in coup-hit Africa appears clear",
#   'timedelta_since_post': datetime.timedelta(seconds=18842, microseconds=472518),
#   'time_since_post': '5h14m',
#   'comments_per_minute': 0.015921876658528816,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 21, 39),
#   'url': 'https://news.ycombinator.com/item?id=37378357',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379857,
#   'num_comments': 1,
#   'title': 'Show HN: Search Engine for GPT and AI Assistants',
#   'timedelta_since_post': datetime.timedelta(seconds=3796, microseconds=377295),
#   'time_since_post': '1h3m',
#   'comments_per_minute': 0.015806111696522657,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 30, 39),
#   'url': 'https://news.ycombinator.com/item?id=37379857',
#   'recent_comments_per_minute': 0.2201834862385321},
#  {'story_id': 37379823,
#   'num_comments': 1,
#   'title': 'How Accurate Were EPAs Predictions of climate change from 40 years ago?',
#   'timedelta_since_post': datetime.timedelta(seconds=4064, microseconds=372168),
#   'time_since_post': '1h7m',
#   'comments_per_minute': 0.014763779527559055,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 26, 12),
#   'url': 'https://news.ycombinator.com/item?id=37379823',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379794,
#   'num_comments': 1,
#   'title': 'Remote Attestation is a WebAuthn first-class citizen',
#   'timedelta_since_post': datetime.timedelta(seconds=4253, microseconds=137561),
#   'time_since_post': '1h10m',
#   'comments_per_minute': 0.014107688690336231,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 23, 13),
#   'url': 'https://news.ycombinator.com/item?id=37379794',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379320,
#   'num_comments': 2,
#   'title': 'Building AI Talent Pipeline: Strategies for Attracting and Retaining AI Talent',
#   'timedelta_since_post': datetime.timedelta(seconds=8715, microseconds=496743),
#   'time_since_post': '2h25m',
#   'comments_per_minute': 0.013769363166953529,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 9, 17),
#   'url': 'https://news.ycombinator.com/item?id=37379320',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378783,
#   'num_comments': 3,
#   'title': 'Chrome extensions can steal plaintext passwords from websites',
#   'timedelta_since_post': datetime.timedelta(seconds=14045, microseconds=936898),
#   'time_since_post': '3h54m',
#   'comments_per_minute': 0.012815948736205054,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 40, 54),
#   'url': 'https://news.ycombinator.com/item?id=37378783',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379742,
#   'num_comments': 1,
#   'title': 'Can Stock Photo Is Closing October 1',
#   'timedelta_since_post': datetime.timedelta(seconds=4823, microseconds=866729),
#   'time_since_post': '1h20m',
#   'comments_per_minute': 0.012440389798880364,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 13, 43),
#   'url': 'https://news.ycombinator.com/item?id=37379742',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379220,
#   'num_comments': 2,
#   'title': 'Programming Languages 2023',
#   'timedelta_since_post': datetime.timedelta(seconds=9690, microseconds=847501),
#   'time_since_post': '2h41m',
#   'comments_per_minute': 0.01238390092879257,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 53, 19),
#   'url': 'https://news.ycombinator.com/item?id=37379220',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379736,
#   'num_comments': 1,
#   'title': 'Show HN: Baseutils – Your daily utils in one place for a faster workflow',
#   'timedelta_since_post': datetime.timedelta(seconds=4861, microseconds=632070),
#   'time_since_post': '1h21m',
#   'comments_per_minute': 0.012343139271754783,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 13, 6),
#   'url': 'https://news.ycombinator.com/item?id=37379736',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378277,
#   'num_comments': 4,
#   'title': 'Ask HN: What kind of fun did you use to have before the HR-organized joy?',
#   'timedelta_since_post': datetime.timedelta(seconds=19623, microseconds=428803),
#   'time_since_post': '5h27m',
#   'comments_per_minute': 0.012230545788105793,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 9),
#   'url': 'https://news.ycombinator.com/item?id=37378277',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379698,
#   'num_comments': 1,
#   'title': 'Chrome Browser blocking .exe downloads even with Safe Browsing disabled',
#   'timedelta_since_post': datetime.timedelta(seconds=5205, microseconds=352448),
#   'time_since_post': '1h26m',
#   'comments_per_minute': 0.011527377521613832,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 7, 23),
#   'url': 'https://news.ycombinator.com/item?id=37379698',
#   'recent_comments_per_minute': 0.05994005994005994},
#  {'story_id': 37379693,
#   'num_comments': 1,
#   'title': 'Share Secrets securely using a url',
#   'timedelta_since_post': datetime.timedelta(seconds=5240, microseconds=34280),
#   'time_since_post': '1h27m',
#   'comments_per_minute': 0.011450381679389313,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 6, 49),
#   'url': 'https://news.ycombinator.com/item?id=37379693',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379002,
#   'num_comments': 2,
#   'title': 'The UK is at risk of running low on water. Why?',
#   'timedelta_since_post': datetime.timedelta(seconds=11900, microseconds=489647),
#   'time_since_post': '3h18m',
#   'comments_per_minute': 0.010084033613445377,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 16, 36),
#   'url': 'https://news.ycombinator.com/item?id=37379002',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378190,
#   'num_comments': 3,
#   'title': 'From FT employment to a $6,500/mo “full-time side-hustle” within 6 months',
#   'timedelta_since_post': datetime.timedelta(seconds=20428, microseconds=230437),
#   'time_since_post': '5h40m',
#   'comments_per_minute': 0.008811435284903074,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 55, 46),
#   'url': 'https://news.ycombinator.com/item?id=37378190',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379491,
#   'num_comments': 1,
#   'title': 'Ask HN: If you’ve used both Svelte and React, which is better?',
#   'timedelta_since_post': datetime.timedelta(seconds=7226, microseconds=620637),
#   'time_since_post': '2h0m',
#   'comments_per_minute': 0.008303349017437033,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 34, 2),
#   'url': 'https://news.ycombinator.com/item?id=37379491',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378747,
#   'num_comments': 2,
#   'title': 'Ask HN: Which CS topics should I study to be able to work with data efficiently?',
#   'timedelta_since_post': datetime.timedelta(seconds=14453, microseconds=853620),
#   'time_since_post': '4h0m',
#   'comments_per_minute': 0.008302774510482253,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 34, 7),
#   'url': 'https://news.ycombinator.com/item?id=37378747',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379332,
#   'num_comments': 1,
#   'title': 'Ask HN: Is the 1 Content for All Over?',
#   'timedelta_since_post': datetime.timedelta(seconds=8611, microseconds=911216),
#   'time_since_post': '2h23m',
#   'comments_per_minute': 0.006967831842991522,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 11),
#   'url': 'https://news.ycombinator.com/item?id=37379332',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379302,
#   'num_comments': 1,
#   'title': 'Hungry caterpillars: new hero emerges in the war against plastic waste',
#   'timedelta_since_post': datetime.timedelta(seconds=8939, microseconds=472011),
#   'time_since_post': '2h28m',
#   'comments_per_minute': 0.006712160196890033,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 5, 34),
#   'url': 'https://news.ycombinator.com/item?id=37379302',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378204,
#   'num_comments': 2,
#   'title': 'Falling in Love with Retro',
#   'timedelta_since_post': datetime.timedelta(seconds=20338, microseconds=22767),
#   'time_since_post': '5h38m',
#   'comments_per_minute': 0.005900285180450389,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 57, 7),
#   'url': 'https://news.ycombinator.com/item?id=37378204',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379160,
#   'num_comments': 1,
#   'title': 'Lua Syntax',
#   'timedelta_since_post': datetime.timedelta(seconds=10362, microseconds=640744),
#   'time_since_post': '2h52m',
#   'comments_per_minute': 0.005790387955993052,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 42, 8),
#   'url': 'https://news.ycombinator.com/item?id=37379160',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379119,
#   'num_comments': 1,
#   'title': 'Guardian and Observer Style Guide',
#   'timedelta_since_post': datetime.timedelta(seconds=10764, microseconds=574409),
#   'time_since_post': '2h59m',
#   'comments_per_minute': 0.005574136008918617,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 35, 27),
#   'url': 'https://news.ycombinator.com/item?id=37379119',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379094,
#   'num_comments': 1,
#   'title': 'Totes Adorbs Truncations [video]',
#   'timedelta_since_post': datetime.timedelta(seconds=11008, microseconds=598131),
#   'time_since_post': '3h3m',
#   'comments_per_minute': 0.005450581395348837,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 31, 24),
#   'url': 'https://news.ycombinator.com/item?id=37379094',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379082,
#   'num_comments': 1,
#   'title': 'Twitter accused of helping Saudi Arabia commit human rights abuses',
#   'timedelta_since_post': datetime.timedelta(seconds=11126, microseconds=317391),
#   'time_since_post': '3h5m',
#   'comments_per_minute': 0.005392773683264426,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 29, 27),
#   'url': 'https://news.ycombinator.com/item?id=37379082',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379081,
#   'num_comments': 1,
#   'title': 'OpenAI Insists on Deadnaming Me',
#   'timedelta_since_post': datetime.timedelta(seconds=11127, microseconds=735463),
#   'time_since_post': '3h5m',
#   'comments_per_minute': 0.005392289026691831,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 29, 26),
#   'url': 'https://news.ycombinator.com/item?id=37379081',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379043,
#   'num_comments': 1,
#   'title': 'Apple will frame iPhone 15 USB-C switch as a consumer win',
#   'timedelta_since_post': datetime.timedelta(seconds=11531, microseconds=299772),
#   'time_since_post': '3h12m',
#   'comments_per_minute': 0.005203364842598214,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 22, 43),
#   'url': 'https://news.ycombinator.com/item?id=37379043',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379030,
#   'num_comments': 1,
#   'title': 'I made a plugin that makes modular synthesis simple and approachable',
#   'timedelta_since_post': datetime.timedelta(seconds=11659, microseconds=89852),
#   'time_since_post': '3h14m',
#   'comments_per_minute': 0.005146238957028905,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 20, 36),
#   'url': 'https://news.ycombinator.com/item?id=37379030',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379004,
#   'num_comments': 1,
#   'title': 'Testing GPT4 Image Recognition (Beta)',
#   'timedelta_since_post': datetime.timedelta(seconds=11897, microseconds=76982),
#   'time_since_post': '3h18m',
#   'comments_per_minute': 0.005043288223921997,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 16, 39),
#   'url': 'https://news.ycombinator.com/item?id=37379004',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378889,
#   'num_comments': 1,
#   'title': 'Big Data Analytics for Gaming – Firebolt',
#   'timedelta_since_post': datetime.timedelta(seconds=13072, microseconds=520909),
#   'time_since_post': '3h37m',
#   'comments_per_minute': 0.004589963280293758,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 57, 6),
#   'url': 'https://news.ycombinator.com/item?id=37378889',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378668,
#   'num_comments': 1,
#   'title': 'Turning $20k Into $500k In 1 Year Challenge',
#   'timedelta_since_post': datetime.timedelta(seconds=15233, microseconds=816319),
#   'time_since_post': '4h13m',
#   'comments_per_minute': 0.003938817041948401,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 21, 31),
#   'url': 'https://news.ycombinator.com/item?id=37378668',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378566,
#   'num_comments': 1,
#   'title': 'SensusQ – a military intelligence management software',
#   'timedelta_since_post': datetime.timedelta(seconds=16566, microseconds=520325),
#   'time_since_post': '4h36m',
#   'comments_per_minute': 0.003621876131836291,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 59, 19),
#   'url': 'https://news.ycombinator.com/item?id=37378566',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378393,
#   'num_comments': 1,
#   'title': 'Improving consistency in a Go crawler with retry logics and network tuning',
#   'timedelta_since_post': datetime.timedelta(seconds=18545, microseconds=282742),
#   'time_since_post': '5h9m',
#   'comments_per_minute': 0.0032353734160150984,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 26, 27),
#   'url': 'https://news.ycombinator.com/item?id=37378393',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378337,
#   'num_comments': 1,
#   'title': 'How Universal Are Our Emotions? (2022)',
#   'timedelta_since_post': datetime.timedelta(seconds=19013, microseconds=966846),
#   'time_since_post': '5h16m',
#   'comments_per_minute': 0.0031557355493609636,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 18, 49),
#   'url': 'https://news.ycombinator.com/item?id=37378337',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378335,
#   'num_comments': 1,
#   'title': 'Show HN: FileSamplesHub – Free sample files to all your testing purposes',
#   'timedelta_since_post': datetime.timedelta(seconds=19035, microseconds=447830),
#   'time_since_post': '5h17m',
#   'comments_per_minute': 0.0031520882584712374,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 18, 28),
#   'url': 'https://news.ycombinator.com/item?id=37378335',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378198,
#   'num_comments': 1,
#   'title': 'Professional Data Recovery Solution for Windows',
#   'timedelta_since_post': datetime.timedelta(seconds=20363, microseconds=972205),
#   'time_since_post': '5h39m',
#   'comments_per_minute': 0.00294652065019889,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 56, 42),
#   'url': 'https://news.ycombinator.com/item?id=37378198',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378167,
#   'num_comments': 1,
#   'title': 'NotYourVocab',
#   'timedelta_since_post': datetime.timedelta(seconds=20716, microseconds=328654),
#   'time_since_post': '5h45m',
#   'comments_per_minute': 0.0028963120293492954,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 51, 15),
#   'url': 'https://news.ycombinator.com/item?id=37378167',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378137,
#   'num_comments': 1,
#   'title': 'High Quality 3D Scene Generation from 2D Source, in Realtime',
#   'timedelta_since_post': datetime.timedelta(seconds=21123, microseconds=249744),
#   'time_since_post': '5h52m',
#   'comments_per_minute': 0.0028405056099985795,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 44, 29),
#   'url': 'https://news.ycombinator.com/item?id=37378137',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380295,
#   'num_comments': 0,
#   'title': 'X faces 2,200 arbitration cases and filing fees over $3M',
#   'timedelta_since_post': datetime.timedelta(seconds=61, microseconds=294763),
#   'time_since_post': '0h1m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 32, 47),
#   'url': 'https://news.ycombinator.com/item?id=37380295',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380270,
#   'num_comments': 0,
#   'title': 'Titanium spikes kill superbugs drug-free by ripping them apart',
#   'timedelta_since_post': datetime.timedelta(seconds=271, microseconds=453365),
#   'time_since_post': '0h4m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 29, 17),
#   'url': 'https://news.ycombinator.com/item?id=37380270',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380253,
#   'num_comments': 0,
#   'title': 'The Statistical Heart of the System',
#   'timedelta_since_post': datetime.timedelta(seconds=420, microseconds=607991),
#   'time_since_post': '0h7m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 26, 48),
#   'url': 'https://news.ycombinator.com/item?id=37380253',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380237,
#   'num_comments': 0,
#   'title': 'Format Floppy Disks with Higher Capacity (1.72 MByte)',
#   'timedelta_since_post': datetime.timedelta(seconds=561, microseconds=750908),
#   'time_since_post': '0h9m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 24, 27),
#   'url': 'https://news.ycombinator.com/item?id=37380237',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380231,
#   'num_comments': 0,
#   'title': 'A detailed record of macOS and its security updates',
#   'timedelta_since_post': datetime.timedelta(seconds=595, microseconds=901461),
#   'time_since_post': '0h9m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 23, 53),
#   'url': 'https://news.ycombinator.com/item?id=37380231',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380227,
#   'num_comments': 0,
#   'title': 'Vaquita',
#   'timedelta_since_post': datetime.timedelta(seconds=617, microseconds=54540),
#   'time_since_post': '0h10m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 23, 32),
#   'url': 'https://news.ycombinator.com/item?id=37380227',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380218,
#   'num_comments': 0,
#   'title': 'BMW, Mercedes launch biggest EV push yet to catch Tesla with new models',
#   'timedelta_since_post': datetime.timedelta(seconds=751, microseconds=210540),
#   'time_since_post': '0h12m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 21, 18),
#   'url': 'https://news.ycombinator.com/item?id=37380218',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380203,
#   'num_comments': 0,
#   'title': 'On Tools and the Aesthetics of Work',
#   'timedelta_since_post': datetime.timedelta(seconds=863, microseconds=802412),
#   'time_since_post': '0h14m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 19, 26),
#   'url': 'https://news.ycombinator.com/item?id=37380203',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380170,
#   'num_comments': 0,
#   'title': 'I Had a Helicopter Mom. I Found Pornhub Anyway',
#   'timedelta_since_post': datetime.timedelta(seconds=1112, microseconds=961076),
#   'time_since_post': '0h18m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 15, 17),
#   'url': 'https://news.ycombinator.com/item?id=37380170',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380169,
#   'num_comments': 0,
#   'title': 'How I Beat Repetitive Stress Injury',
#   'timedelta_since_post': datetime.timedelta(seconds=1117, microseconds=124695),
#   'time_since_post': '0h18m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 15, 13),
#   'url': 'https://news.ycombinator.com/item?id=37380169',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380162,
#   'num_comments': 0,
#   'title': 'Thirteenth Salary',
#   'timedelta_since_post': datetime.timedelta(seconds=1175, microseconds=276976),
#   'time_since_post': '0h19m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 14, 15),
#   'url': 'https://news.ycombinator.com/item?id=37380162',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380124,
#   'num_comments': 0,
#   'title': 'The Matrix Arcade: A Visual Explorable of Matrix Transformations',
#   'timedelta_since_post': datetime.timedelta(seconds=1538, microseconds=845379),
#   'time_since_post': '0h25m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 8, 12),
#   'url': 'https://news.ycombinator.com/item?id=37380124',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380108,
#   'num_comments': 0,
#   'title': 'High Volume, Bandwidth Heavy Infrastructure on the Cheap (2017) [video]',
#   'timedelta_since_post': datetime.timedelta(seconds=1729, microseconds=330),
#   'time_since_post': '0h28m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 5, 2),
#   'url': 'https://news.ycombinator.com/item?id=37380108',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380104,
#   'num_comments': 0,
#   'title': 'Is macOS’s new XProtect behavioural security preparing to go live?',
#   'timedelta_since_post': datetime.timedelta(seconds=1743, microseconds=153314),
#   'time_since_post': '0h29m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 4, 48),
#   'url': 'https://news.ycombinator.com/item?id=37380104',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380100,
#   'num_comments': 0,
#   'title': 'History of Cartography: Volumes One, Two, Three, Four, and Six (1987)',
#   'timedelta_since_post': datetime.timedelta(seconds=1765, microseconds=314522),
#   'time_since_post': '0h29m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 4, 26),
#   'url': 'https://news.ycombinator.com/item?id=37380100',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380095,
#   'num_comments': 0,
#   'title': 'Study uses motion capture to determine what makes the best free-throw shooters',
#   'timedelta_since_post': datetime.timedelta(seconds=1836, microseconds=463207),
#   'time_since_post': '0h30m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 3, 15),
#   'url': 'https://news.ycombinator.com/item?id=37380095',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380070,
#   'num_comments': 0,
#   'title': 'Connection coalescing with ORIGIN Frames: fewer DNS queries, fewer connections',
#   'timedelta_since_post': datetime.timedelta(seconds=2019, microseconds=419948),
#   'time_since_post': '0h33m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 0, 13),
#   'url': 'https://news.ycombinator.com/item?id=37380070',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380068,
#   'num_comments': 0,
#   'title': 'Fight for the Future',
#   'timedelta_since_post': datetime.timedelta(seconds=2024, microseconds=562282),
#   'time_since_post': '0h33m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 7, 0, 8),
#   'url': 'https://news.ycombinator.com/item?id=37380068',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380054,
#   'num_comments': 0,
#   'title': 'What 0 to 6 Months of Photography Has Taught Me',
#   'timedelta_since_post': datetime.timedelta(seconds=2170, microseconds=711110),
#   'time_since_post': '0h36m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 57, 42),
#   'url': 'https://news.ycombinator.com/item?id=37380054',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37380023,
#   'num_comments': 0,
#   'title': 'Build a Product, Not a Chatbot',
#   'timedelta_since_post': datetime.timedelta(seconds=2444, microseconds=853564),
#   'time_since_post': '0h40m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 53, 8),
#   'url': 'https://news.ycombinator.com/item?id=37380023',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379995,
#   'num_comments': 0,
#   'title': 'Why Visma chose 1Password as its enterprise password manager',
#   'timedelta_since_post': datetime.timedelta(seconds=2659, microseconds=542),
#   'time_since_post': '0h44m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 49, 34),
#   'url': 'https://news.ycombinator.com/item?id=37379995',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379987,
#   'num_comments': 0,
#   'title': 'Invasive species pose major global threats to nature, economies, and health',
#   'timedelta_since_post': datetime.timedelta(seconds=2711, microseconds=140684),
#   'time_since_post': '0h45m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 48, 42),
#   'url': 'https://news.ycombinator.com/item?id=37379987',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379984,
#   'num_comments': 0,
#   'title': 'TinyLlama project aims to pretrain a 1.1B Llama model on 3T tokens',
#   'timedelta_since_post': datetime.timedelta(seconds=2765, microseconds=284360),
#   'time_since_post': '0h46m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 47, 48),
#   'url': 'https://news.ycombinator.com/item?id=37379984',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379980,
#   'num_comments': 0,
#   'title': 'Our Story – Why We Built ThriveSparrow',
#   'timedelta_since_post': datetime.timedelta(seconds=2790, microseconds=429029),
#   'time_since_post': '0h46m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 47, 23),
#   'url': 'https://news.ycombinator.com/item?id=37379980',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379935,
#   'num_comments': 0,
#   'title': '“Space: 1999” takes place between the year of its broadcast and today',
#   'timedelta_since_post': datetime.timedelta(seconds=3188, microseconds=573705),
#   'time_since_post': '0h53m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 40, 45),
#   'url': 'https://news.ycombinator.com/item?id=37379935',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379932,
#   'num_comments': 0,
#   'title': 'Google turns 25: A look at the world’s top performing searches',
#   'timedelta_since_post': datetime.timedelta(seconds=3246, microseconds=723458),
#   'time_since_post': '0h54m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 39, 47),
#   'url': 'https://news.ycombinator.com/item?id=37379932',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379931,
#   'num_comments': 0,
#   'title': 'Yggdrasil',
#   'timedelta_since_post': datetime.timedelta(seconds=3252, microseconds=889019),
#   'time_since_post': '0h54m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 39, 41),
#   'url': 'https://news.ycombinator.com/item?id=37379931',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379911,
#   'num_comments': 0,
#   'title': 'Every Billable Hour Is Amateur Hour',
#   'timedelta_since_post': datetime.timedelta(seconds=3431, microseconds=60755),
#   'time_since_post': '0h57m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 36, 43),
#   'url': 'https://news.ycombinator.com/item?id=37379911',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379880,
#   'num_comments': 0,
#   'title': 'Australia rescues sick researcher from Antarctica',
#   'timedelta_since_post': datetime.timedelta(seconds=3659, microseconds=964960),
#   'time_since_post': '1h0m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 32, 55),
#   'url': 'https://news.ycombinator.com/item?id=37379880',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379861,
#   'num_comments': 0,
#   'title': '4 Reasons Echidnas Are Remarkable',
#   'timedelta_since_post': datetime.timedelta(seconds=3775, microseconds=235798),
#   'time_since_post': '1h2m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 31),
#   'url': 'https://news.ycombinator.com/item?id=37379861',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379848,
#   'num_comments': 0,
#   'title': 'Open Source Anti-Patterns with Kelsey Hightower',
#   'timedelta_since_post': datetime.timedelta(seconds=3873, microseconds=91632),
#   'time_since_post': '1h4m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 29, 23),
#   'url': 'https://news.ycombinator.com/item?id=37379848',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379822,
#   'num_comments': 0,
#   'title': 'AppleWorks',
#   'timedelta_since_post': datetime.timedelta(seconds=4095, microseconds=844543),
#   'time_since_post': '1h8m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 25, 41),
#   'url': 'https://news.ycombinator.com/item?id=37379822',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379796,
#   'num_comments': 0,
#   'title': 'Study reveals how little things can reduce hip fractures',
#   'timedelta_since_post': datetime.timedelta(seconds=4248, microseconds=991450),
#   'time_since_post': '1h10m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 23, 17),
#   'url': 'https://news.ycombinator.com/item?id=37379796',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379772,
#   'num_comments': 0,
#   'title': 'Transforming an Arcade Machine into a WFH-Friendly Grafana Dashboard',
#   'timedelta_since_post': datetime.timedelta(seconds=4450, microseconds=535584),
#   'time_since_post': '1h14m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 19, 56),
#   'url': 'https://news.ycombinator.com/item?id=37379772',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379771,
#   'num_comments': 0,
#   'title': 'How to Add a Visual Label to Web Content',
#   'timedelta_since_post': datetime.timedelta(seconds=4456, microseconds=702281),
#   'time_since_post': '1h14m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 19, 50),
#   'url': 'https://news.ycombinator.com/item?id=37379771',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379740,
#   'num_comments': 0,
#   'title': 'Practice and Experience',
#   'timedelta_since_post': datetime.timedelta(seconds=4843, microseconds=306092),
#   'time_since_post': '1h20m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 13, 24),
#   'url': 'https://news.ycombinator.com/item?id=37379740',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379738,
#   'num_comments': 0,
#   'title': 'Sea of Stars( New Exclusive PS Plus Extra)',
#   'timedelta_since_post': datetime.timedelta(seconds=4850, microseconds=466849),
#   'time_since_post': '1h20m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 13, 17),
#   'url': 'https://news.ycombinator.com/item?id=37379738',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379714,
#   'num_comments': 0,
#   'title': 'Laurenz Albe: Conditional foreign keys and polymorphism in SQL: 4 Methods',
#   'timedelta_since_post': datetime.timedelta(seconds=5003, microseconds=43903),
#   'time_since_post': '1h23m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 10, 45),
#   'url': 'https://news.ycombinator.com/item?id=37379714',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379704,
#   'num_comments': 0,
#   'title': 'Architecting Kubernetes clusters – choosing a worker node size',
#   'timedelta_since_post': datetime.timedelta(seconds=5128, microseconds=199781),
#   'time_since_post': '1h25m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 6, 8, 40),
#   'url': 'https://news.ycombinator.com/item?id=37379704',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379625,
#   'num_comments': 0,
#   'title': 'Show HN: Random Month Generator',
#   'timedelta_since_post': datetime.timedelta(seconds=5868, microseconds=439834),
#   'time_since_post': '1h37m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 56, 21),
#   'url': 'https://news.ycombinator.com/item?id=37379625',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379610,
#   'num_comments': 0,
#   'title': 'Thoughts about Object Linking in the NeXTStep systems',
#   'timedelta_since_post': datetime.timedelta(seconds=6006, microseconds=577740),
#   'time_since_post': '1h40m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 54, 3),
#   'url': 'https://news.ycombinator.com/item?id=37379610',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379582,
#   'num_comments': 0,
#   'title': 'Show HN: Lineage-Diff for dbt data projects (no account required)',
#   'timedelta_since_post': datetime.timedelta(seconds=6291, microseconds=810050),
#   'time_since_post': '1h44m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 49, 18),
#   'url': 'https://news.ycombinator.com/item?id=37379582',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379557,
#   'num_comments': 0,
#   'title': 'Clean Architecture by refactoring a Go project',
#   'timedelta_since_post': datetime.timedelta(seconds=6528, microseconds=953880),
#   'time_since_post': '1h48m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 45, 21),
#   'url': 'https://news.ycombinator.com/item?id=37379557',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379541,
#   'num_comments': 0,
#   'title': 'DebateKG: Automatic Policy Debate Case Creation with Semantic Knowledge Graphs',
#   'timedelta_since_post': datetime.timedelta(seconds=6681, microseconds=103880),
#   'time_since_post': '1h51m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 42, 49),
#   'url': 'https://news.ycombinator.com/item?id=37379541',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379535,
#   'num_comments': 0,
#   'title': 'Battle Of The Flagships (58 Headphones Compared) (2007)',
#   'timedelta_since_post': datetime.timedelta(seconds=6755, microseconds=263353),
#   'time_since_post': '1h52m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 41, 35),
#   'url': 'https://news.ycombinator.com/item?id=37379535',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379469,
#   'num_comments': 0,
#   'title': 'Show HN: Interactively explore unstructured datasets from your dataframe',
#   'timedelta_since_post': datetime.timedelta(seconds=7411, microseconds=34733),
#   'time_since_post': '2h3m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 30, 58),
#   'url': 'https://news.ycombinator.com/item?id=37379469',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379466,
#   'num_comments': 0,
#   'title': 'Head – A simple guide to HTML <head> elements',
#   'timedelta_since_post': datetime.timedelta(seconds=7449, microseconds=192809),
#   'time_since_post': '2h4m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 30, 20),
#   'url': 'https://news.ycombinator.com/item?id=37379466',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379447,
#   'num_comments': 0,
#   'title': 'The barriers that impede “stitching” collaboration between Commons and Wikipedia',
#   'timedelta_since_post': datetime.timedelta(seconds=7560, microseconds=354210),
#   'time_since_post': '2h6m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 28, 29),
#   'url': 'https://news.ycombinator.com/item?id=37379447',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379427,
#   'num_comments': 0,
#   'title': 'An introduction to personal knowledge management',
#   'timedelta_since_post': datetime.timedelta(seconds=7787, microseconds=499499),
#   'time_since_post': '2h9m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 24, 42),
#   'url': 'https://news.ycombinator.com/item?id=37379427',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379372,
#   'num_comments': 0,
#   'title': 'Cohere AI Chronicle – Challenging Tech Giants with AI for All',
#   'timedelta_since_post': datetime.timedelta(seconds=8197, microseconds=604158),
#   'time_since_post': '2h16m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 17, 53),
#   'url': 'https://news.ycombinator.com/item?id=37379372',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379323,
#   'num_comments': 0,
#   'title': 'The Usefulness of a Memory Guides Where the Brain Saves It',
#   'timedelta_since_post': datetime.timedelta(seconds=8676, microseconds=325467),
#   'time_since_post': '2h24m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 9, 56),
#   'url': 'https://news.ycombinator.com/item?id=37379323',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379316,
#   'num_comments': 0,
#   'title': 'Can you use memory errors as a source of randomness for cryptography?',
#   'timedelta_since_post': datetime.timedelta(seconds=8731, microseconds=148936),
#   'time_since_post': '2h25m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 9, 2),
#   'url': 'https://news.ycombinator.com/item?id=37379316',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379314,
#   'num_comments': 0,
#   'title': "How 'Jaws' misrepresented the great white (2015)",
#   'timedelta_since_post': datetime.timedelta(seconds=8782, microseconds=319253),
#   'time_since_post': '2h26m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 8, 11),
#   'url': 'https://news.ycombinator.com/item?id=37379314',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379299,
#   'num_comments': 0,
#   'title': 'Instant GraphQL APIs for MongoDB Atlas',
#   'timedelta_since_post': datetime.timedelta(seconds=8951, microseconds=925477),
#   'time_since_post': '2h29m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 5, 22),
#   'url': 'https://news.ycombinator.com/item?id=37379299',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379298,
#   'num_comments': 0,
#   'title': 'What Comes Up Must First Go Down',
#   'timedelta_since_post': datetime.timedelta(seconds=8965, microseconds=164725),
#   'time_since_post': '2h29m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 5, 9),
#   'url': 'https://news.ycombinator.com/item?id=37379298',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379297,
#   'num_comments': 0,
#   'title': 'The Battle over Books3 Could Change AI Forever',
#   'timedelta_since_post': datetime.timedelta(seconds=8983, microseconds=297923),
#   'time_since_post': '2h29m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 4, 51),
#   'url': 'https://news.ycombinator.com/item?id=37379297',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379269,
#   'num_comments': 0,
#   'title': 'India’s Elite Tech Schools Are a Golden Ticket with a Dark Side',
#   'timedelta_since_post': datetime.timedelta(seconds=9207, microseconds=296838),
#   'time_since_post': '2h33m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 1, 21),
#   'url': 'https://news.ycombinator.com/item?id=37379269',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379261,
#   'num_comments': 0,
#   'title': 'Show HN: Comgra: A library for debugging and understanding neural networks',
#   'timedelta_since_post': datetime.timedelta(seconds=9277, microseconds=440893),
#   'time_since_post': '2h34m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 5, 0, 11),
#   'url': 'https://news.ycombinator.com/item?id=37379261',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379238,
#   'num_comments': 0,
#   'title': 'LLMs vs Human Judgement',
#   'timedelta_since_post': datetime.timedelta(seconds=9511, microseconds=515968),
#   'time_since_post': '2h38m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 56, 18),
#   'url': 'https://news.ycombinator.com/item?id=37379238',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379224,
#   'num_comments': 0,
#   'title': 'The rootless, brilliant and tragic life of Joseph Roth',
#   'timedelta_since_post': datetime.timedelta(seconds=9664, microseconds=676725),
#   'time_since_post': '2h41m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 53, 45),
#   'url': 'https://news.ycombinator.com/item?id=37379224',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379211,
#   'num_comments': 0,
#   'title': 'Continuously variable ebike transmission promises up to 20% more range',
#   'timedelta_since_post': datetime.timedelta(seconds=9755, microseconds=488395),
#   'time_since_post': '2h42m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 52, 15),
#   'url': 'https://news.ycombinator.com/item?id=37379211',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379150,
#   'num_comments': 0,
#   'title': 'Supabase moves from project-based to organization-based billing',
#   'timedelta_since_post': datetime.timedelta(seconds=10476, microseconds=85639),
#   'time_since_post': '2h54m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 40, 15),
#   'url': 'https://news.ycombinator.com/item?id=37379150',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37379137,
# ...
#   'time_since_post': '3h27m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 7, 51),
#   'url': 'https://news.ycombinator.com/item?id=37378947',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378943,
#   'num_comments': 0,
#   'title': 'Trunk Based Development',
#   'timedelta_since_post': datetime.timedelta(seconds=12467, microseconds=82478),
#   'time_since_post': '3h27m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 7, 11),
#   'url': 'https://news.ycombinator.com/item?id=37378943',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378942,
#   'num_comments': 0,
#   'title': 'The Innovation Tension: Where Creativity Meets Value',
#   'timedelta_since_post': datetime.timedelta(seconds=12480, microseconds=218519),
#   'time_since_post': '3h28m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 6, 58),
#   'url': 'https://news.ycombinator.com/item?id=37378942',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378925,
#   'num_comments': 0,
#   'title': 'One UI 6 gives your Galaxy S23 an AI-powered voice that sounds just like you',
#   'timedelta_since_post': datetime.timedelta(seconds=12685, microseconds=369395),
#   'time_since_post': '3h31m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 4, 3, 33),
#   'url': 'https://news.ycombinator.com/item?id=37378925',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378880,
#   'num_comments': 0,
#   'title': 'Astro 3.0',
#   'timedelta_since_post': datetime.timedelta(seconds=13168, microseconds=116362),
#   'time_since_post': '3h39m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 55, 31),
#   'url': 'https://news.ycombinator.com/item?id=37378880',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378840,
#   'num_comments': 0,
#   'title': 'Anything but Tech Debt',
#   'timedelta_since_post': datetime.timedelta(seconds=13479, microseconds=272179),
#   'time_since_post': '3h44m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 50, 20),
#   'url': 'https://news.ycombinator.com/item?id=37378840',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378835,
#   'num_comments': 0,
#   'title': 'Fixing Year 2038 Coordinating the 64-bit time_t ABI migration [video]',
#   'timedelta_since_post': datetime.timedelta(seconds=13569, microseconds=421782),
#   'time_since_post': '3h46m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 48, 50),
#   'url': 'https://news.ycombinator.com/item?id=37378835',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378829,
#   'num_comments': 0,
#   'title': 'Who Deserves Amphetamines?',
#   'timedelta_since_post': datetime.timedelta(seconds=13653, microseconds=580007),
#   'time_since_post': '3h47m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 47, 26),
#   'url': 'https://news.ycombinator.com/item?id=37378829',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378823,
#   'num_comments': 0,
#   'title': 'Ask HN: What Will Programs/Apps Replace Twitter Integration With?',
#   'timedelta_since_post': datetime.timedelta(seconds=13712, microseconds=772486),
#   'time_since_post': '3h48m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 46, 27),
#   'url': 'https://news.ycombinator.com/item?id=37378823',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378743,
#   'num_comments': 0,
#   'title': 'A memory-safe sudo, written in Rust (sic)',
#   'timedelta_since_post': datetime.timedelta(seconds=14506, microseconds=497938),
#   'time_since_post': '4h1m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 33, 15),
#   'url': 'https://news.ycombinator.com/item?id=37378743',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378713,
#   'num_comments': 0,
#   'title': 'Space Time Information Triangle',
#   'timedelta_since_post': datetime.timedelta(seconds=14776, microseconds=634772),
#   'time_since_post': '4h6m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 28, 45),
#   'url': 'https://news.ycombinator.com/item?id=37378713',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378702,
#   'num_comments': 0,
#   'title': 'Ask HN: Do you know any company that only offers GraphQL and no REST',
#   'timedelta_since_post': datetime.timedelta(seconds=14853, microseconds=801363),
#   'time_since_post': '4h7m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 27, 28),
#   'url': 'https://news.ycombinator.com/item?id=37378702',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378681,
#   'num_comments': 0,
#   'title': 'Educational Hypertext and the “Why” Link',
#   'timedelta_since_post': datetime.timedelta(seconds=15103, microseconds=970275),
#   'time_since_post': '4h11m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 23, 18),
#   'url': 'https://news.ycombinator.com/item?id=37378681',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378672,
#   'num_comments': 0,
#   'title': 'Turn Figma comments instantly into tasks on Jira, GitHub',
#   'timedelta_since_post': datetime.timedelta(seconds=15184, microseconds=128882),
#   'time_since_post': '4h13m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 21, 58),
#   'url': 'https://news.ycombinator.com/item?id=37378672',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378662,
#   'num_comments': 0,
#   'title': "Small Details to Improve Your Website's Experience",
#   'timedelta_since_post': datetime.timedelta(seconds=15274, microseconds=211380),
#   'time_since_post': '4h14m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 20, 51),
#   'url': 'https://news.ycombinator.com/item?id=37378662',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378642,
#   'num_comments': 0,
#   'title': 'Oppenheimer, Mission: Impossible and the Cost of Downplaying VFX',
#   'timedelta_since_post': datetime.timedelta(seconds=15466, microseconds=372242),
#   'time_since_post': '4h17m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 3, 17, 39),
#   'url': 'https://news.ycombinator.com/item?id=37378642',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378460,
#   'num_comments': 0,
#   'title': 'The boss I never wanted to be',
#   'timedelta_since_post': datetime.timedelta(seconds=17691, microseconds=934454),
#   'time_since_post': '4h54m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 40, 34),
#   'url': 'https://news.ycombinator.com/item?id=37378460',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378456,
#   'num_comments': 0,
#   'title': "Edison's 1890 Phonograph Doll",
#   'timedelta_since_post': datetime.timedelta(seconds=17726, microseconds=93245),
#   'time_since_post': '4h55m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 40),
#   'url': 'https://news.ycombinator.com/item?id=37378456',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378439,
#   'num_comments': 0,
#   'title': 'Show HN: Fine-Tuning Splade and SparseEmbed LMs',
#   'timedelta_since_post': datetime.timedelta(seconds=17934, microseconds=156055),
#   'time_since_post': '4h58m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 36, 37),
#   'url': 'https://news.ycombinator.com/item?id=37378439',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378430,
#   'num_comments': 0,
#   'title': 'Locating ‘identifiers’ quickly (ARM NEON edition)',
#   'timedelta_since_post': datetime.timedelta(seconds=18048, microseconds=301647),
#   'time_since_post': '5h0m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 34, 43),
#   'url': 'https://news.ycombinator.com/item?id=37378430',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378426,
#   'num_comments': 0,
#   'title': '“The Computer” by Jens Müller and Julius Wiedemann',
#   'timedelta_since_post': datetime.timedelta(seconds=18102, microseconds=453870),
#   'time_since_post': '5h1m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 33, 49),
#   'url': 'https://news.ycombinator.com/item?id=37378426',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378411,
#   'num_comments': 0,
#   'title': 'Show HN: Rapidgzip – Truly Parallel Gzip Decompression with 10 GB/s',
#   'timedelta_since_post': datetime.timedelta(seconds=18387, microseconds=605937),
#   'time_since_post': '5h6m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 29, 4),
#   'url': 'https://news.ycombinator.com/item?id=37378411',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378396,
#   'num_comments': 0,
#   'title': 'Harsh Environments: Space Radiation Environment, Effects, and Mitigation (2008) [pdf]',
#   'timedelta_since_post': datetime.timedelta(seconds=18538, microseconds=131105),
#   'time_since_post': '5h8m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 26, 34),
#   'url': 'https://news.ycombinator.com/item?id=37378396',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378332,
#   'num_comments': 0,
#   'title': 'Americans Are Fake and the Dutch Are Rude? (2022)',
#   'timedelta_since_post': datetime.timedelta(seconds=19059, microseconds=876797),
#   'time_since_post': '5h17m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 18, 4),
#   'url': 'https://news.ycombinator.com/item?id=37378332',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378308,
#   'num_comments': 0,
#   'title': 'Human evaluation of automatically generated text',
#   'timedelta_since_post': datetime.timedelta(seconds=19272, microseconds=816784),
#   'time_since_post': '5h21m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 14, 50),
#   'url': 'https://news.ycombinator.com/item?id=37378308',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378306,
#   'num_comments': 0,
#   'title': 'PEP 503 – Simple Repository API',
#   'timedelta_since_post': datetime.timedelta(seconds=19293, microseconds=975765),
#   'time_since_post': '5h21m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 14, 29),
#   'url': 'https://news.ycombinator.com/item?id=37378306',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378303,
#   'num_comments': 0,
#   'title': 'Short Ruby News – edition 57',
#   'timedelta_since_post': datetime.timedelta(seconds=19345, microseconds=138663),
#   'time_since_post': '5h22m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 13, 38),
#   'url': 'https://news.ycombinator.com/item?id=37378303',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378286,
#   'num_comments': 0,
#   'title': 'Schillace Laws of Semantic AI',
#   'timedelta_since_post': datetime.timedelta(seconds=19527, microseconds=292672),
#   'time_since_post': '5h25m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 10, 36),
#   'url': 'https://news.ycombinator.com/item?id=37378286',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378236,
#   'num_comments': 0,
#   'title': 'PicoKeys: A Personal Secure Key with open hardware and software',
#   'timedelta_since_post': datetime.timedelta(seconds=19978, microseconds=573689),
#   'time_since_post': '5h32m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 3, 6),
#   'url': 'https://news.ycombinator.com/item?id=37378236',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378234,
#   'num_comments': 0,
#   'title': 'Temporal Fuzzing I: Memory Models',
#   'timedelta_since_post': datetime.timedelta(seconds=20012, microseconds=715477),
#   'time_since_post': '5h33m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 2, 32),
#   'url': 'https://news.ycombinator.com/item?id=37378234',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378225,
#   'num_comments': 0,
#   'title': 'How the Most Useless Branch of Math Could Save Your Life',
#   'timedelta_since_post': datetime.timedelta(seconds=20102, microseconds=866092),
#   'time_since_post': '5h35m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 2, 1, 2),
#   'url': 'https://news.ycombinator.com/item?id=37378225',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378180,
#   'num_comments': 0,
#   'title': 'Glee: Publish Markdown Files into Ghost Blog Posts',
#   'timedelta_since_post': datetime.timedelta(seconds=20514, microseconds=173791),
#   'time_since_post': '5h41m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 54, 21),
#   'url': 'https://news.ycombinator.com/item?id=37378180',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378174,
#   'num_comments': 0,
#   'title': 'Yet another ICML award fiasco',
#   'timedelta_since_post': datetime.timedelta(seconds=20609, microseconds=176651),
#   'time_since_post': '5h43m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 53, 2),
#   'url': 'https://news.ycombinator.com/item?id=37378174',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378163,
#   'num_comments': 0,
#   'title': 'Dasher – efficient and accessible text entry',
#   'timedelta_since_post': datetime.timedelta(seconds=20764, microseconds=770445),
#   'time_since_post': '5h46m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 50, 27),
#   'url': 'https://news.ycombinator.com/item?id=37378163',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378162,
#   'num_comments': 0,
#   'title': 'Six Ages 2: Lights Going Out review: a story-generator',
#   'timedelta_since_post': datetime.timedelta(seconds=20781, microseconds=932972),
#   'time_since_post': '5h46m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 50, 10),
#   'url': 'https://news.ycombinator.com/item?id=37378162',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378157,
#   'num_comments': 0,
#   'title': 'Moon base: Bangor scientists design fuel to live in space',
#   'timedelta_since_post': datetime.timedelta(seconds=20950, microseconds=98539),
#   'time_since_post': '5h49m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 47, 22),
#   'url': 'https://news.ycombinator.com/item?id=37378157',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378106,
#   'num_comments': 0,
#   'title': 'Comic Book Plus: Comics Archive',
#   'timedelta_since_post': datetime.timedelta(seconds=21394, microseconds=58634),
#   'time_since_post': '5h56m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 39, 59),
#   'url': 'https://news.ycombinator.com/item?id=37378106',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378099,
#   'num_comments': 0,
#   'title': 'Animal mazes are a popular class of gaming apps',
#   'timedelta_since_post': datetime.timedelta(seconds=21512, microseconds=238512),
#   'time_since_post': '5h58m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 38, 1),
#   'url': 'https://news.ycombinator.com/item?id=37378099',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378086,
#   'num_comments': 0,
#   'title': 'Burning Man: Thousands of festival attendees remain stuck in the Nevada desert',
#   'timedelta_since_post': datetime.timedelta(seconds=21562, microseconds=412032),
#   'time_since_post': '5h59m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 37, 11),
#   'url': 'https://news.ycombinator.com/item?id=37378086',
#   'recent_comments_per_minute': 0},
#  {'story_id': 37378084,
#   'num_comments': 0,
#   'title': 'Cartoon Painting – Draw Sketc Pictures Paint Board Pad',
#   'timedelta_since_post': datetime.timedelta(seconds=21572, microseconds=592394),
#   'time_since_post': '5h59m',
#   'comments_per_minute': 0.0,
#   'story_datetime': datetime.datetime(2023, 9, 4, 1, 37, 1),
#   'url': 'https://news.ycombinator.com/item?id=37378084',
#   'recent_comments_per_minute': 0}]

# %%
comment_velocity_df = pd.DataFrame.from_records(comment_velocity_sorted_stories_display)
recent_comment_velocity_df = pd.DataFrame.from_records(comment_velocity_sorted_stories_display)

# %%
comment_velocity_df
# Out:
#      story_id  num_comments  \
# 0    37379534            56
# 1    37379801            32
# 2    37379272            52
# 3    37378669            80
# 4    37376686           150
# ..        ...           ...
# 495  37373237             0
# 496  37373180             0
# 497  37373177             0
# 498  37373150             0
# 499  37373092             0
#
#                                                  title   timedelta_since_post  \
# 0    Reddit faces content quality concerns after it... 0 days 01:52:40.436283
# 1     I built a Plane Spotter in 120 secs with ChatGPT 0 days 01:10:19.007076
# 2    TV Museum Will Die in 48 Hours Unless Sony Ret... 0 days 02:32:23.449544
# 3                           The curl-wget Venn diagram 0 days 04:13:24.294482
# 4                           Glove80 Ergonomic Keyboard 0 days 10:47:10.732236
# ..                                                 ...                    ...
# 495  Court Rules on Civilian Drones Used to Record ... 0 days 18:51:34.285422
# 496                         Using ZRAM Instead of Swap 0 days 18:58:40.026572
# 497  Russia Linked Hackers Attack UK Ministry of De... 0 days 18:58:58.170254
# 498             Ask HN: Where do I get bank card BINs? 0 days 19:01:01.317053
# 499  The First Stable Release of a Memory Safe Sudo... 0 days 19:06:11.472544
#
#     time_since_post  comments_per_minute      story_datetime  \
# 0             1h52m             0.497041 2023-09-04 05:41:30
# 1             1h10m             0.455084 2023-09-04 06:23:38
# 2             2h32m             0.341245 2023-09-04 05:02:11
# 3             4h13m             0.315706 2023-09-04 03:21:38
# 4            10h47m             0.231780 2023-09-03 20:52:04
# ..              ...                  ...                 ...
# 495          18h51m             0.000000 2023-09-03 12:59:14
# 496          18h58m             0.000000 2023-09-03 12:52:53
# 497          18h58m             0.000000 2023-09-03 12:52:35
# 498           19h1m             0.000000 2023-09-03 12:50:32
# 499           19h6m             0.000000 2023-09-03 12:45:22
#
#                                                url  recent_comments_per_minute
# 0    https://news.ycombinator.com/item?id=37379534                    0.693900
# 1    https://news.ycombinator.com/item?id=37379801                    1.159251
# 2    https://news.ycombinator.com/item?id=37379272                    0.564952
# 3    https://news.ycombinator.com/item?id=37378669                    0.896940
# 4    https://news.ycombinator.com/item?id=37376686                    1.538202
# ..                                             ...                         ...
# 495  https://news.ycombinator.com/item?id=37373237                    0.000000
# 496  https://news.ycombinator.com/item?id=37373180                    0.000000
# 497  https://news.ycombinator.com/item?id=37373177                    0.000000
# 498  https://news.ycombinator.com/item?id=37373150                    0.000000
# 499  https://news.ycombinator.com/item?id=37373092                    0.000000
#
# [500 rows x 9 columns]

# %%
c = (alt.Chart(comment_velocity_df)
        .mark_area(opacity=0.3)
        .encode(
            x='timedelta_since_post',
            y='comments_per_minute',
            color='title',
    ))
st.altair_chart(c, use_container_width=True)

# %%
st.dataframe(comment_velocity_df)

# %%
recent_comment_velocity_df.to_csv('recent_comment_velocity_df.csv')

# %%
time.max
# Out:
# datetime.time(23, 59, 59, 999999)

# %%
comment_timeseries_csv_filename = 'comment_timeseries_0.1.csv'
stories_csv_filename = 'stories_0.1.csv'

story_parse_dates = ['story_datetime']
comment_parse_dates = ['comment_timestamp']
story_df = pd.read_csv(stories_csv_filename, parse_dates=story_parse_dates)
comment_df = pd.read_csv(comment_timeseries_csv_filename, parse_dates=comment_parse_dates)

recent_comment_metrics = comment_df.groupby(
        ['story_id']
    ).agg(
        {
            'comment_timestamp': ['min', 'count'],
        }
    )

# groupby / agg with multiple aggs gives a multindex, need to drop a level to join
recent_comment_metrics.columns = recent_comment_metrics.columns.droplevel(0)
recent_comment_metrics = recent_comment_metrics.rename(
    {'min': 'earliest_recent_comment_timestamp', 'count': 'num_recent_comments'},
    axis=1
)

recent_comment_metrics
#joined_df = story_df.merge(recent_comment_metrics, on=['story_id'])

#joined_df
# Out:
#          earliest_recent_comment_timestamp  num_recent_comments
# story_id
# 37373410               2023-09-03 14:03:49                   10
# 37373503               2023-09-03 13:58:36                    2
# 37373560               2023-09-03 13:43:13                    6
# 37373635               2023-09-03 14:05:29                   61
# 37373637               2023-09-03 13:40:23                    1
# ...                                    ...                  ...
# 37380303               2023-09-04 07:34:33                    1
# 37380343               2023-09-04 07:37:50                    1
# 37380353               2023-09-04 07:47:05                    3
# 37380464               2023-09-04 07:53:57                    1
# 37380489               2023-09-04 07:53:11                    1
#
# [214 rows x 2 columns]
